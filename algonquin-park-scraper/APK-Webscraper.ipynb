# %% [markdown]
# # Patrick's Absolute Beginner Guide to Building a Webscraper (Sort of)

# %% [markdown]
# ## Scraping for Algonquin Park Fire Photos

# %% [markdown]
# This notebook aims to search the Algonquin Park Archives online website for image files that are related to fires in the Park, and collect the links to these photos into a single .csv document. The python requests library and beautiful soup package will be required to run this notebook, so please install those before attempting to follow along with this project.
#
# This notebook serves as a tool to gather historical photos for my research on the topics of Algonquin Park, the timber trade in the Ottawa Valley, and the role of fire in the Indigenous, logging, and settlement histories of the area. The list of photo links that this notebook will generate will give me quick access to the complete collection of the APK Archives Online. This will be especially helpful to me next year when I am planning to participate in an MA program that deals with the topic of timber in the Ottawa Valley and fire in the Park.
#
# As per data, this notebook only uses the url of the online archives in order to gain access to and parse the html of the webpage for the desired links. The particular url I have used is for the photo search page with the search criteria set simply to 'fire'. This search provides 200 results out of almost 7000 photos searched, however it appears that each time the url is refreshed, the photos appear in a different order. This can be disorienting during the initial process of examining the html with the inspect function on a web browser, but causes no issues once the coding phase is started.
#
# Additionally, not all the results are loaded onto a single webpage. Rather, you have to hit 'next page' to see the remaining results. This means that to get all the photos, we would need to run through the scraper twice, the second time with the page 2 url. This will be touched on again in the following section.
#
# Finally, this notebook is meant for those arts students in university who quite honestly have not the slightest clue of how coding works. For those people, congrats on managing to open up the notebook and view this page, that's a great first step. I'm going to walk you through this 'simple' scraper and explain every single minute thing to the best of my abilities, because that is what I needed even just to get to this point.

# %% [markdown]
# ## The Basics of html

# %% [markdown]
# Before we start parsing a website, we first have to understand html and how url's are formatted.
#
# First let's look at the entire url.
# https://algonquinpark.pastperfectonline.com/photo?utf8=%E2%9C%93&search_criteria=fire&searchButton=Search
# Our first part here is the main website, algonquinpark.pastperfectonline.com, so that's the first thing we need to know.
#
# The second part from photo? to the & indicates the "image only" search section of the archive webpage. Search_criteria=fire means that fire is the keyword that was put into the search bar. searchButton indicates the search button that gets clicked in order to initiate the search. [^1]
#
# Keep in mind that this scraper only works for the specific page that the url links to, and only for the data that is contained on that specific page. This means that just going to the photo search page, without searching for a key word, would yield no results. In other words the search page doesn't automatically link to the entire site inventory. Additionally, in the case of the fire photos, 200 results are acquired, but they don't display all of them on the first page. We would as such need to run through the notebook a second time with the url for 'page 2 results' in order to get the second half of the photo links and titles.
#
# Overall, our entire process here is based off of this url, so it's best we understand why we're using it the way we are.
#
# [1] Martin Breuss, "Beautiful Soup: Build a Webscraper with Python," Real Python, https://realpython.com/beautiful-soup-web-scraper-python/

# %% [markdown]
# ## Establishing Contact with the Website

# %%
#set up code to communicate with website
import requests
#url used is from APK Archives photo search for key word 'fire'
URL = 'https://algonquinpark.pastperfectonline.com/photo?utf8=%E2%9C%93&search_criteria=fire&searchButton=Search'
#requests.get(url) communicates with website server and 'gets' the data (the html), data is stored in 'response'
response = requests.get(URL)
#print(response) indicates successfull communication if printed response is [200]
print(response)
# Out:
# <Response [200]>

# %% [markdown]
# ## Looking at the Raw html

# %%
#html is the code that makes up a website
# a string is a text unit in code
#.text renders data in text form
html_string = response.text
#therefore printing the above code gives you the raw html of the whole page
print(html_string)
#use the inspect function on your browser to compare the html of the original to ours
# Out:
# <!DOCTYPE html>
# <html lang="en">
#
#
#   <head>
#      <script>
#     (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#     (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#     m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#     })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#     ga('create', 'UA-84695581-1', 'auto', 'clientTracker');
#     ga('clientTracker.send', 'pageview');
#
#
#     </script>
#       <title>The Friends of Algonquin Park : Online Collections</title>
#     <meta name="viewport" content="width=device-width"/>
#
#       <link href="https://s3.amazonaws.com/pastperfectonline/sitecontent/reset.css" media="screen" rel="stylesheet" />
#       <link href="https://s3.amazonaws.com/pastperfectonline/sitecontent/text.css" media="screen" rel="stylesheet" />
#       <link href="/assets/jquery-ui.min.css?body=1" media="screen" rel="stylesheet" />
#       <link href="https://s3.amazonaws.com/pastperfectonline/sitecontent/960.css" media="screen" rel="stylesheet" />
#       <link href="https://s3.amazonaws.com/pastperfectonline/sitecontent/pastperfect_squares.css" media="screen" rel="stylesheet" />
#       <link href="https://s3.amazonaws.com/pastperfectonline/sitecontent/pastperfect_print.css" media="print" rel="stylesheet" />
#
#     <link href="/assets/jquery.fancybox.css?body=1" media="screen" rel="stylesheet" />
#
#
#
#     <script src="/assets/jquery.js?body=1"></script>
#     <script src="/assets/jquery-ui.min.js?body=1"></script>
#     <script src="/assets/jquery.fancybox.js?body=1"></script>
#     <script src="/assets/pastperfect.js?body=1"></script>
#
#     <meta name="google-site-verification" content="Mrs2Li1H2dpkeKsIdNGrzOPpbaQLLNOXc9VsK29x0K0" />
# <meta name="msvalidate.01" content="F52D94122EDBA3DBFD8C1E1EA934F0FE" />
#
# <link rel="icon" type="image/png" href="http://www.algonquinpark.on.ca/favicon.ico" />
#
#     <meta content="authenticity_token" name="csrf-param" />
# <meta content="SyF+VVTtVK57AnKD1o6/BoTgqnGIRcwrLkcxxEXHNfg=" name="csrf-token" />
#
#     <style>
#       body {
# background-color:#ffffff;
# }
#
# .container_12{
# box-shadow:0 0 .9em #333333;
# }
#
# .header{
# padding:5px 0;
# background-color:#7e8768;
# text-align:center;
# }
#
# footer {
# background-color:#576b66;
# color:#ffffff;
# font-size:12px;
# }
#
# .topNav a {
# background-color:#5d684e;
# border-color:#5d684e;
# border-radius:0;
# color:#ffffff;
# font-weight:bold;
# font-size:14px;
# }
#
# .topNav a:hover {
# background-color:#93A174;
# border-color:#93A174;
# color:#353E70;
# }
#
# .leftNav a {
# background-color:#5d684e;
# border-color:#5d684e;
# border-radius:0;
# color:#ffffff;
# font-weight:bold;
# }
#
# .leftNav a:hover {
# background-color:#93A174;
# border-color:#93A174;
# color:#353E70;
# }
#
# .topSearchArea input[type=submit] {
# background-color:#5d684e;
# border-color:#5d684e;
# color:#ffffff;
# }
#
# .topSearchArea input[type=submit]:hover {
# background-color:#93A174;
# border-color:#93A174;
# color:#353E70;
# }
#
# .advancedSearchArea input[type=submit] {
# background-color:#5d684e;
# border-color:#5d684e;
# color:#ffffff;
# }
#
# .advancedSearchArea input[type=submit]:hover {
# background-color:#93A174;
# border-color:#93A174;
# color:#353E70;
# }
#
# .vocabulary_letters a, .vocabulary_words_div a {
# color:#B01E24;
# }
#
# .vocabulary_letters a:hover, .vocabulary_words_div a:hover {
# color:#B01E24;
# }
#
# a#randomImagesFooterLink {
# font-size: 16px;
# font-weight: bold;
# }
#
# a {
# color:#B01E24;
# text-decoration: underline;
# }
#
# a:hover {
# color:#B01E24;
# text-decoration: none;
# }
#
# .indvResultDetails h1 {
# line-height:20px;
# }
#
# .indvResultDetails a {
# color:#5d684e;
# font-size:20px;
# }
#
# .indvResultDetails a:hover {
# color:#93A174;
# }
#
# .indvImage:hover {
# border: solid 2px #93A174;
# }
#
# .largeImage:hover {
# border: solid 2px #93A174;
# }
#
# img.indvImage,img.indvImage:hover{
# border:none;
# cursor:default;
# }
#
# .highlightedWord {
# color:#353E70;
# font-weight:bold;
# }
#
# .searchResultTitle Number {
# color:#353E70;
# }
#
# @media screen and (min-width:640px){
# .topNav{
# background-color:#5d684e;
# }
# .topNav li{
# margin:0;
# }
# .topNav a,.topNav a:hover{
# border-left-color:#ffffff;
# margin-left:-4px;
# }
# .topNav li:first-child a{
# border-left-color:#5d684e;
# }
# .activities{
# margin-left:-10px;
# }
# }
#
# @media screen and (max-width:640px){
# .activities{
# display:none;
# }
# }
#
#       .floatRight{
#         float:right;
#       }
#
#       .floatLeft{
#         float:left;
#       }
#
#       .fullWidth{
#         width:100%;
#       }
#
#     </style>
#   </head>
# <body>
#
#
#
# <div class="container_12">
#   <div class="skipnav"> <a href="#maincontent">Skip to content</a></div>
#
#
#     <header>
#       <div class="grid_12 header">
#         <a href="http://www.algonquinpark.on.ca/" target="_blank"><img src="https://s3.amazonaws.com/pastperfectonline/museumlogos/logos/552/original/logo.jpg?1474917706" alt="Museum logo"><img src="https://s3.amazonaws.com/pastperfectonline/museumlogos/images/1332/original/logo_text.jpg?1474917953" alt="Logo text"></a>
#
#       </div>
#     </header>
#   <div class="grid_2 leftNav">
#       <nav>
#       <ul>
#           <li id="navCustom">
#               <a class="button" href="http://www.algonquinpark.on.ca/">Algonquin Park</a>
#
#           </li>
#
#         <li id="navLanding">
#           <a class="button" href="/">Archives Online</a>
#         </li>
#         <li id="navKeyword">
#           <a class="button" href="/search">Keyword Search</a>
#         </li>
#         <li id="navAdvanced">
#           <a class="button" href="/advancedsearch">Advanced Search</a>
#         </li>
#         <li id="navRandom">
#           <a class="button" href="/randomimages">Random Images</a>
#         </li>
#
#             <li id="navArchives">
#               <a class="button" href="/archive">Archives</a>
#             </li>
#             <li id="navPhotos">
#               <a class="button" href="/photo">Images</a>
#             </li>
#             <li id="navLibrary">
#               <a class="button" href="/library">Library</a>
#             </li>
#             <li id="navObjects">
#               <a class="button" href="/webobject">Artifacts</a>
#             </li>
#       </ul>
#     </nav>
#   </div>
#   <div class="grid_10" id="maincontent">
#     <form accept-charset="UTF-8" action="photo" method="get"><div style="margin:0;padding:0;display:inline"><input name="utf8" type="hidden" value="&#x2713;" /></div>
# <div class="topSearchArea">
#   <input aria-label="Enter Search Criteria" class="search_box" id="search_criteria" name="search_criteria" placeholder="Enter Photo Search Criteria Here" type="text" value="fire" />
#   <input name="searchButton" type="submit" value="Search" />
#   <br/>
#   <input aria-label="Items with Images Only" id="only_images" name="only_images" type="checkbox" /> Items with Images Only
#
#         <p>
#           <strong>Search Hints:</strong> To search by phrase wrap your criteria in quotes. ex: "Find me"
#         </p>
#
# </div>
# </form>
#       <h1 class="searchResultTitle">
#         <number>200</number> results found. Records searched: 6904
#       </h1>
#
#         <div class="indvResult">
#           <table>
#             <tr>
#               <td>
#                   <div class="indvImage">
#
#
#
#                         <a href="/photo/5A297BAC-FAE7-4B00-A770-122996321625"><img alt="Image of Campfire" src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/002/thumbs/20141625.jpg" title="Image of Campfire" /></a>
#
#
#
#
#
#                   </div>
#
#               </td>
#               <td>
#                 <div class="indvResultDetails">
#                   <h1>
#                         <a href="/photo/5A297BAC-FAE7-4B00-A770-122996321625">Campfire</a>
#
#                   </h1>
#
#                   <p>
#
#                           people sitting around a camp <span class='highlightedWord'>fire</span>. The picture was taken at night and it is very dark. The <span class='highlightedWord'>fire</span> is in the
#                   </p>
#                   <h4><strong>Record Type:</strong> Images</h4>
#                 </div>
#               </td>
#             </tr>
#           </table>
#         </div>
#         <div class="indvResult">
#           <table>
#             <tr>
#               <td>
#                   <div class="indvImage">
#
#
#
#                         <a href="/photo/5C95D582-2A8C-4683-99A5-019573344532"><img alt="Image of 1980 - The tower cabin at Trout Lake, June 1980." src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/015/thumbs/a05729.jpg" title="Image of 1980 - The tower cabin at Trout Lake, June 1980." /></a>
#
#
#
#
#
#                   </div>
#
#               </td>
#               <td>
#                 <div class="indvResultDetails">
#                   <h1>
#                         <a href="/photo/5C95D582-2A8C-4683-99A5-019573344532">1980 - The tower cabin at Trout Lake, June 1980.</a>
#
#                   </h1>
#
#                   <p>
#
#                           cabin
# tower
# ranger
# <span class='highlightedWord'>fire</span>
# park building
# log cabin
#                   </p>
#                   <h4><strong>Record Type:</strong> Images</h4>
#                 </div>
#               </td>
#             </tr>
#           </table>
#         </div>
#         <div class="indvResult">
#           <table>
#             <tr>
#               <td>
#                   <div class="indvImage">
#
#
#
#                         <a href="/photo/889588A1-6DD9-4020-954A-700198065756"><img alt="Image of 1922 - Wooden fire tower." src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/008/thumbs/a02065.jpg" title="Image of 1922 - Wooden fire tower." /></a>
#
#
#
#
#
#                   </div>
#
#               </td>
#               <td>
#                 <div class="indvResultDetails">
#                   <h1>
#                         <a href="/photo/889588A1-6DD9-4020-954A-700198065756">1922 - Wooden fire tower.</a>
#
#                   </h1>
#
#                   <p>
#
#                           Wooden <span class='highlightedWord'>fire</span> tower.
#
#                           <span class='highlightedWord'>fire</span> tower
# towers
#
#                           Wooden <span class='highlightedWord'>fire</span> tower at Paul Lapinski's, Bonnechere.
#                   </p>
#                   <h4><strong>Record Type:</strong> Images</h4>
#                 </div>
#               </td>
#             </tr>
#           </table>
#         </div>
#         <div class="indvResult">
#           <table>
#             <tr>
#               <td>
#                   <div class="indvImage">
#
#
#
#                         <a href="/photo/286A5AC8-3F18-47C0-8AF0-512415283746"><img alt="Image of 1977 - Barron Canyon Fire" src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/012/thumbs/a03753.jpg" title="Image of 1977 - Barron Canyon Fire" /></a>
#
#
#
#
#
#                   </div>
#
#               </td>
#               <td>
#                 <div class="indvResultDetails">
#                   <h1>
#                         <a href="/photo/286A5AC8-3F18-47C0-8AF0-512415283746">1977 - Barron Canyon Fire</a>
#
#                   </h1>
#
#                   <p>
#
#                           Barron Canyon <span class='highlightedWord'>Fire</span>
#
#                           <span class='highlightedWord'>Fire</span>
#
#                           Barron Canyon <span class='highlightedWord'>Fire</span>, #28, 21/5/77, ground <span class='highlightedWord'>fire</span>, burned 10 acres. This photo was taken a couple of
#                   </p>
#                   <h4><strong>Record Type:</strong> Images</h4>
#                 </div>
#               </td>
#             </tr>
#           </table>
#         </div>
#         <div class="indvResult">
#           <table>
#             <tr>
#               <td>
#                   <div class="indvImage">
#
#
#
#                         <a href="/photo/6DE99AF3-8976-4E7D-B5F9-697364532868"><img alt="Image of Camp Tanamakoon" src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/017/thumbs/a06784.jpg" title="Image of Camp Tanamakoon" /></a>
#
#
#
#
#
#                   </div>
#
#               </td>
#               <td>
#                 <div class="indvResultDetails">
#                   <h1>
#                         <a href="/photo/6DE99AF3-8976-4E7D-B5F9-697364532868">Camp Tanamakoon</a>
#
#                   </h1>
#
#                   <p>
#
#                           canoe
# canoe trip
# Camp Tanamakoon
# campsite
# cook
# <span class='highlightedWord'>fire</span>
# recreation
#
#                           Group photograph of Camp Tanamakoon canoe trippers cooking a meal around the camp <span class='highlightedWord'>fire</span>.
#                   </p>
#                   <h4><strong>Record Type:</strong> Images</h4>
#                 </div>
#               </td>
#             </tr>
#           </table>
#         </div>
#         <div class="indvResult">
#           <table>
#             <tr>
#               <td>
#                   <div class="indvImage">
#
#
#
#                         <a href="/photo/9E3D6749-FE52-43E1-81BE-324877324689"><img alt="Image of 1976 - Preston fire tower cabin" src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/011/thumbs/a03353.jpg" title="Image of 1976 - Preston fire tower cabin" /></a>
#
#
#
#
#
#                   </div>
#
#               </td>
#               <td>
#                 <div class="indvResultDetails">
#                   <h1>
#                         <a href="/photo/9E3D6749-FE52-43E1-81BE-324877324689">1976 - Preston fire tower cabin</a>
#
#                   </h1>
#
#                   <p>
#
#                           Preston <span class='highlightedWord'>fire</span> tower cabin
#
#                           <span class='highlightedWord'>fire</span> tower
# cabin
#
#                           Preston <span class='highlightedWord'>fire</span> tower cabin, Tattler Lake, July 25, 1976
#                   </p>
#                   <h4><strong>Record Type:</strong> Images</h4>
#                 </div>
#               </td>
#             </tr>
#           </table>
#         </div>
#         <div class="indvResult">
#           <table>
#             <tr>
#               <td>
#                   <div class="indvImage">
#
#
#
#                         <a href="/photo/5195654B-80C6-4A21-90AB-834956724276"><img alt="Image of 1962 - Fire, Master Twp." src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/015/thumbs/a05522.jpg" title="Image of 1962 - Fire, Master Twp." /></a>
#
#
#
#
#
#                   </div>
#
#               </td>
#               <td>
#                 <div class="indvResultDetails">
#                   <h1>
#                         <a href="/photo/5195654B-80C6-4A21-90AB-834956724276">1962 - Fire, Master Twp.</a>
#
#                   </h1>
#
#                   <p>
#
#                           <span class='highlightedWord'>Fire</span>, Master Twp.
#
#                           <span class='highlightedWord'>Fire</span>
# aerial view
# forest <span class='highlightedWord'>fire</span>
# natural disturbance
#
#                           <span class='highlightedWord'>Fire</span>, Lot 7 Con. 3, Master Township, June 16, 1962.
#                   </p>
#                   <h4><strong>Record Type:</strong> Images</h4>
#                 </div>
#               </td>
#             </tr>
#           </table>
#         </div>
#         <div class="indvResult">
#           <table>
#             <tr>
#               <td>
#                   <div class="indvImage">
#
#
#
#                         <a href="/photo/FA4396A8-7A8C-4495-AECA-255041297429"><img alt="Image of 1973 - Site of Staniforth&#39;s mill" src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/014/thumbs/a05266.jpg" title="Image of 1973 - Site of Staniforth&#39;s mill" /></a>
#
#
#
#
#
#                   </div>
#
#               </td>
#               <td>
#                 <div class="indvResultDetails">
#                   <h1>
#                         <a href="/photo/FA4396A8-7A8C-4495-AECA-255041297429">1973 - Site of Staniforth&#39;s mill</a>
#
#                   </h1>
#
#                   <p>
#
#                           <span class='highlightedWord'>fire</span>
# mill
#
# lumber yard
#
#                           Site of Staniforth's mill at Kiosk, after the <span class='highlightedWord'>fire</span>, July 1973.
#                   </p>
#                   <h4><strong>Record Type:</strong> Images</h4>
#                 </div>
#               </td>
#             </tr>
#           </table>
#         </div>
#         <div class="indvResult">
#           <table>
#             <tr>
#               <td>
#                   <div class="indvImage">
#
#
#
#                         <a href="/photo/463072AE-CF5B-4CB9-AC09-375820449882"><img alt="Image of 1925 - East Arm Opeongo Lake." src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/018/thumbs/a02117.jpg" title="Image of 1925 - East Arm Opeongo Lake." /></a>
#
#
#
#
#
#                   </div>
#
#               </td>
#               <td>
#                 <div class="indvResultDetails">
#                   <h1>
#                         <a href="/photo/463072AE-CF5B-4CB9-AC09-375820449882">1925 - East Arm Opeongo Lake.</a>
#
#                   </h1>
#
#                   <p>
#
#                           Two men cooking over <span class='highlightedWord'>fire</span>, canoes on shore, on the East Arm of Opeongo Lake.
#                   </p>
#                   <h4><strong>Record Type:</strong> Images</h4>
#                 </div>
#               </td>
#             </tr>
#           </table>
#         </div>
#         <div class="indvResult">
#           <table>
#             <tr>
#               <td>
#                   <div class="indvImage">
#
#
#
#                         <a href="/photo/B084B7D7-92E4-41CB-8FD3-486430523990"><img alt="Image of Campfire" src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/017/thumbs/a06527.jpg" title="Image of Campfire" /></a>
#
#
#
#
#
#                   </div>
#
#               </td>
#               <td>
#                 <div class="indvResultDetails">
#                   <h1>
#                         <a href="/photo/B084B7D7-92E4-41CB-8FD3-486430523990">Campfire</a>
#
#                   </h1>
#
#                   <p>
#
#                           cook
# cooking
# <span class='highlightedWord'>fire</span>
# camp <span class='highlightedWord'>fire</span>
# camp
#                   </p>
#                   <h4><strong>Record Type:</strong> Images</h4>
#                 </div>
#               </td>
#             </tr>
#           </table>
#         </div>
#         <div class="indvResult">
#           <table>
#             <tr>
#               <td>
#                   <div class="indvImage">
#
#
#
#                         <a href="/photo/64A8A7DC-E9F9-4DD4-8E04-295762460218"><img alt="Image of Jack Burchat and one of the Rangers." src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/010/thumbs/a03043.jpg" title="Image of Jack Burchat and one of the Rangers." /></a>
#
#
#
#
#
#                   </div>
#
#               </td>
#               <td>
#                 <div class="indvResultDetails">
#                   <h1>
#                         <a href="/photo/64A8A7DC-E9F9-4DD4-8E04-295762460218">Jack Burchat and one of the Rangers.</a>
#
#                   </h1>
#
#                   <p>
#
#                           <span class='highlightedWord'>fire</span> rangers
# rangers
# railway
#                   </p>
#                   <h4><strong>Record Type:</strong> Images</h4>
#                 </div>
#               </td>
#             </tr>
#           </table>
#         </div>
#         <div class="indvResult">
#           <table>
#             <tr>
#               <td>
#                   <div class="indvImage">
#
#
#
#                         <a href="/photo/4A31D48F-7283-4191-83B4-271333032700"><img alt="Image of Making maple syrup." src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/009/thumbs/a02625.jpg" title="Image of Making maple syrup." /></a>
#
#
#
#
#
#                   </div>
#
#               </td>
#               <td>
#                 <div class="indvResultDetails">
#                   <h1>
#                         <a href="/photo/4A31D48F-7283-4191-83B4-271333032700">Making maple syrup.</a>
#
#                   </h1>
#
#                   <p>
#
#                           People standing around a <span class='highlightedWord'>fire</span> making maple syrup at Cache Lake.
#                   </p>
#                   <h4><strong>Record Type:</strong> Images</h4>
#                 </div>
#               </td>
#             </tr>
#           </table>
#         </div>
#         <div class="indvResult">
#           <table>
#             <tr>
#               <td>
#                   <div class="indvImage">
#
#
#
#                         <a href="/photo/15169E29-875C-4FB2-8429-987041858607"><img alt="Image of 1974 - Fire tower cabin, White Trout Lake." src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/009/thumbs/a02574.jpg" title="Image of 1974 - Fire tower cabin, White Trout Lake." /></a>
#
#
#
#
#
#                   </div>
#
#               </td>
#               <td>
#                 <div class="indvResultDetails">
#                   <h1>
#                         <a href="/photo/15169E29-875C-4FB2-8429-987041858607">1974 - Fire tower cabin, White Trout Lake.</a>
#
#                   </h1>
#
#                   <p>
#
#                           <span class='highlightedWord'>Fire</span> tower cabin, White Trout Lake.
#
#                           Bill Calvert walking toward White Trout <span class='highlightedWord'>fire</span> tower cabin.
#                   </p>
#                   <h4><strong>Record Type:</strong> Images</h4>
#                 </div>
#               </td>
#             </tr>
#           </table>
#         </div>
#         <div class="indvResult">
#           <table>
#             <tr>
#               <td>
#                   <div class="indvImage">
#
#
#
#                         <a href="/photo
/></a>
#
#
#
#
#
#                   </div>
#
#               </td>
#               <td>
#                 <div class="indvResultDetails">
#                   <h1>
#                         <a href="/photo/39CBD41E-1673-4ACE-995D-177699718219">June 28, 1955. - Aerial of fire - &quot;Treasure Island&quot;, Tea Lake, June 28, 1955.</a>
#
#                   </h1>
#
#                   <p>
#
#                           Aerial of <span class='highlightedWord'>fire</span> - "Treasure Island", Tea Lake, June 28, 1955.
#
#                           A picture of an island on Tea Lake which is on <span class='highlightedWord'>fire</span>.
#                   </p>
#                   <h4><strong>Record Type:</strong> Images</h4>
#                 </div>
#               </td>
#             </tr>
#           </table>
#         </div>
#         <div class="indvResult">
#           <table>
#             <tr>
#               <td>
#                   <div class="indvImage">
#
#
#
#                         <a href="/photo/E86069C2-B864-445A-948A-529075534824"><img alt="Image of 1939 - Hauling Logs" src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/007/thumbs/a01061.jpg" title="Image of 1939 - Hauling Logs" /></a>
#
#
#
#
#
#                   </div>
#
#               </td>
#               <td>
#                 <div class="indvResultDetails">
#                   <h1>
#                         <a href="/photo/E86069C2-B864-445A-948A-529075534824">1939 - Hauling Logs</a>
#
#                   </h1>
#
#                   <p>
#
#                           Men standing beside a tuck hauling a load of logs on a sleigh. In the "Report on Forest <span class='highlightedWord'>Fire</span>
#                   </p>
#                   <h4><strong>Record Type:</strong> Images</h4>
#                 </div>
#               </td>
#             </tr>
#           </table>
#         </div>
#         <div class="indvResult">
#           <table>
#             <tr>
#               <td>
#                   <div class="indvImage">
#
#
#
#                         <a href="/photo/2EE15277-BB37-4489-96D5-506305070486"><img alt="Image of Ranger Cabin - Barnet Depot - Burntroot Lake." src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/008/thumbs/a01523.jpg" title="Image of Ranger Cabin - Barnet Depot - Burntroot Lake." /></a>
#
#
#
#
#
#                   </div>
#
#               </td>
#               <td>
#                 <div class="indvResultDetails">
#                   <h1>
#                         <a href="/photo/2EE15277-BB37-4489-96D5-506305070486">Ranger Cabin - Barnet Depot - Burntroot Lake.</a>
#
#                   </h1>
#
#                   <p>
#
#                           Picture of shovel and forest <span class='highlightedWord'>fire</span> poster hanging on the wall of the ranger cabin at the Barnet
#                   </p>
#                   <h4><strong>Record Type:</strong> Images</h4>
#                 </div>
#               </td>
#             </tr>
#           </table>
#         </div>
#         <div class="indvResult">
#           <table>
#             <tr>
#               <td>
#                   <div class="indvImage">
#
#
#
#                         <a href="/photo/07DA2E3F-063E-43E9-A618-200343606319"><img alt="Image of Deputy Chief Ranger&#39;s office at Stonecliffe." src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/015/thumbs/a05492.jpg" title="Image of Deputy Chief Ranger&#39;s office at Stonecliffe." /></a>
#
#
#
#
#
#                   </div>
#
#               </td>
#               <td>
#                 <div class="indvResultDetails">
#                   <h1>
#                         <a href="/photo/07DA2E3F-063E-43E9-A618-200343606319">Deputy Chief Ranger&#39;s office at Stonecliffe.</a>
#
#                   </h1>
#
#                   <p>
#
#                           office
# garage
# <span class='highlightedWord'>fire</span>
#
#                           Deputy Chief Ranger's office (L), and garage (R), following the <span class='highlightedWord'>fire</span> at Stonecliffe.
#                   </p>
#                   <h4><strong>Record Type:</strong> Images</h4>
#                 </div>
#               </td>
#             </tr>
#           </table>
#         </div>
#         <div class="indvResult">
#           <table>
#             <tr>
#               <td>
#                   <div class="indvImage">
#
#
#
#                         <a href="/photo/90EBAD42-8655-4692-97DB-167717486174"><img alt="Image of Trout Lake fire tower" src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/016/thumbs/a06291.jpg" title="Image of Trout Lake fire tower" /></a>
#
#
#
#
#
#                   </div>
#
#               </td>
#               <td>
#                 <div class="indvResultDetails">
#                   <h1>
#                         <a href="/photo/90EBAD42-8655-4692-97DB-167717486174">Trout Lake fire tower</a>
#
#                   </h1>
#
#                   <p>
#
#                           Trout Lake <span class='highlightedWord'>fire</span> tower
#
#                           <span class='highlightedWord'>fire</span>
# tower
#
#                           Trout Lake <span class='highlightedWord'>fire</span> tower.
#                   </p>
#                   <h4><strong>Record Type:</strong> Images</h4>
#                 </div>
#               </td>
#             </tr>
#           </table>
#         </div>
#         <div class="indvResult">
#           <table>
#             <tr>
#               <td>
#                   <div class="indvImage">
#
#
#
#                         <a href="/photo/E91FA749-0078-41CB-9E93-170310853238"><img alt="Image of Fire." src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/015/thumbs/a05523.jpg" title="Image of Fire." /></a>
#
#
#
#
#
#                   </div>
#
#               </td>
#               <td>
#                 <div class="indvResultDetails">
#                   <h1>
#                         <a href="/photo/E91FA749-0078-41CB-9E93-170310853238">Fire.</a>
#
#                   </h1>
#
#                   <p>
#
#                           <span class='highlightedWord'>Fire</span>.
#
#                           aerial view
# <span class='highlightedWord'>fire</span>
# forest <span class='highlightedWord'>fire</span>
# natural disturbance
#
#                           <span class='highlightedWord'>Fire</span>.
#                   </p>
#                   <h4><strong>Record Type:</strong> Images</h4>
#                 </div>
#               </td>
#             </tr>
#           </table>
#         </div>
#         <div class="indvResult">
#           <table>
#             <tr>
#               <td>
#                   <div class="indvImage">
#
#
#
#                         <a href="/photo/E7DD080D-03A6-431F-A352-594405900080"><img alt="Image of 1968 - Opeongo Lodge after the fire." src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/015/thumbs/a05409.jpg" title="Image of 1968 - Opeongo Lodge after the fire." /></a>
#
#
#
#
#
#                   </div>
#
#               </td>
#               <td>
#                 <div class="indvResultDetails">
#                   <h1>
#                         <a href="/photo/E7DD080D-03A6-431F-A352-594405900080">1968 - Opeongo Lodge after the fire.</a>
#
#                   </h1>
#
#                   <p>
#
#                           Opeongo Lodge after the <span class='highlightedWord'>fire</span>.
#
#                           lodge
# <span class='highlightedWord'>fire</span>
#
#                           Opeongo Lodge, Opeongo lake, after the <span class='highlightedWord'>fire</span>, 1968. Opeongo Lodge was operated by the Avery family
#                   </p>
#                   <h4><strong>Record Type:</strong> Images</h4>
#                 </div>
#               </td>
#             </tr>
#           </table>
#         </div>
#         <div class="indvResult">
#           <table>
#             <tr>
#               <td>
#                   <div class="indvImage">
#
#
#
#                         <a href="/photo/A833C586-B138-4061-B0E3-785438375747"><img alt="Image of ca. 1926 - Camp Tanamakoon" src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/017/thumbs/a06688.jpg" title="Image of ca. 1926 - Camp Tanamakoon" /></a>
#
#
#
#
#
#                   </div>
#
#               </td>
#               <td>
#                 <div class="indvResultDetails">
#                   <h1>
#                         <a href="/photo/A833C586-B138-4061-B0E3-785438375747">ca. 1926 - Camp Tanamakoon</a>
#
#                   </h1>
#
#                   <p>
#
#                           Camp Tanamakoon
# campers
# lunch
# <span class='highlightedWord'>fire</span>
# recreation
#
#                           Camp Tanamakoon "Chickasaw" campers staging a lunch <span class='highlightedWord'>fire</span>.
#                   </p>
#                   <h4><strong>Record Type:</strong> Images</h4>
#                 </div>
#               </td>
#             </tr>
#           </table>
#         </div>
#         <div class="indvResult">
#           <table>
#             <tr>
#               <td>
#                   <div class="indvImage">
#
#
#
# ...
#
#
#
#
#
#                   </div>
#
#               </td>
#               <td>
#                 <div class="indvResultDetails">
#                   <h1>
#                         <a href="/photo/AB4047BC-CF8D-4DCB-A9C0-793755596830">Wooden fire tower</a>
#
#                   </h1>
#
#                   <p>
#
#                           Wooden <span class='highlightedWord'>fire</span> tower
#
#                           <span class='highlightedWord'>fire</span>
# <span class='highlightedWord'>fire</span> tower
# tower
# <span class='highlightedWord'>fire</span> prevention
#
#                           Wooden <span class='highlightedWord'>fire</span> tower, Location ?
#                   </p>
#                   <h4><strong>Record Type:</strong> Images</h4>
#                 </div>
#               </td>
#             </tr>
#           </table>
#         </div>
#         <div class="indvResult">
#           <table>
#             <tr>
#               <td>
#                   <div class="indvImage">
#
#
#
#                         <a href="/photo/B164F1FF-73BE-4420-94EA-242927384252"><img alt="Image of 1977 - Three Trailers Loaded With Logs From Nominigan Lodge" src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/012/thumbs/a04184.jpg" title="Image of 1977 - Three Trailers Loaded With Logs From Nominigan Lodge" /></a>
#
#
#
#
#
#                   </div>
#
#               </td>
#               <td>
#                 <div class="indvResultDetails">
#                   <h1>
#                         <a href="/photo/B164F1FF-73BE-4420-94EA-242927384252">1977 - Three Trailers Loaded With Logs From Nominigan Lodge</a>
#
#                   </h1>
#
#                   <p>
#
#                           ; and at least one group of people had built a <span class='highlightedWord'>fire</span> using some of the logs. These logs were all tagged
#                   </p>
#                   <h4><strong>Record Type:</strong> Images</h4>
#                 </div>
#               </td>
#             </tr>
#           </table>
#         </div>
#         <div class="indvResult">
#           <table>
#             <tr>
#               <td>
#                   <div class="indvImage">
#
#
#
#                         <a href="/photo/260A991C-D835-496F-9C1F-820761807939"><img alt="Image of 1980 - The tower cabin at Birchcliffe Lake, October 1980." src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/015/thumbs/a05779.jpg" title="Image of 1980 - The tower cabin at Birchcliffe Lake, October 1980." /></a>
#
#
#
#
#
#                   </div>
#
#               </td>
#               <td>
#                 <div class="indvResultDetails">
#                   <h1>
#                         <a href="/photo/260A991C-D835-496F-9C1F-820761807939">1980 - The tower cabin at Birchcliffe Lake, October 1980.</a>
#
#                   </h1>
#
#                   <p>
#
#                           tower
# cabin
# <span class='highlightedWord'>fire</span>
# ranger
#                   </p>
#                   <h4><strong>Record Type:</strong> Images</h4>
#                 </div>
#               </td>
#             </tr>
#           </table>
#         </div>
#         <div class="indvResult">
#           <table>
#             <tr>
#               <td>
#                   <div class="indvImage">
#
#
#
#                         <a href="/photo/8D2F937F-31A0-4F42-9EE1-286037210553"><img alt="Image of Jack Burchat and Hill at Kiosk." src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/010/thumbs/a03036.jpg" title="Image of Jack Burchat and Hill at Kiosk." /></a>
#
#
#
#
#
#                   </div>
#
#               </td>
#               <td>
#                 <div class="indvResultDetails">
#                   <h1>
#                         <a href="/photo/8D2F937F-31A0-4F42-9EE1-286037210553">Jack Burchat and Hill at Kiosk.</a>
#
#                   </h1>
#
#                   <p>
#
#                           <span class='highlightedWord'>fire</span> rangers
# rangers
#                   </p>
#                   <h4><strong>Record Type:</strong> Images</h4>
#                 </div>
#               </td>
#             </tr>
#           </table>
#         </div>
#         <div class="indvResult">
#           <table>
#             <tr>
#               <td>
#                   <div class="indvImage">
#
#
#
#                         <a href="/photo/D8A5CAFF-43D3-4B79-BC96-239844795850"><img alt="Image of Garage, Stonecliffe." src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/015/thumbs/a05490.jpg" title="Image of Garage, Stonecliffe." /></a>
#
#
#
#
#
#                   </div>
#
#               </td>
#               <td>
#                 <div class="indvResultDetails">
#                   <h1>
#                         <a href="/photo/D8A5CAFF-43D3-4B79-BC96-239844795850">Garage, Stonecliffe.</a>
#
#                   </h1>
#
#                   <p>
#
#                           <span class='highlightedWord'>fire</span>
# garage
#                   </p>
#                   <h4><strong>Record Type:</strong> Images</h4>
#                 </div>
#               </td>
#             </tr>
#           </table>
#         </div>
#         <div class="indvResult">
#           <table>
#             <tr>
#               <td>
#                   <div class="indvImage">
#
#
#
#                         <a href="/photo/43C0088D-1416-4209-B1CA-811698665925"><img alt="Image of 1962 - Burning ranger cabin at Three Mile Lake" src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/015/thumbs/a05800.jpg" title="Image of 1962 - Burning ranger cabin at Three Mile Lake" /></a>
#
#
#
#
#
#                   </div>
#
#               </td>
#               <td>
#                 <div class="indvResultDetails">
#                   <h1>
#                         <a href="/photo/43C0088D-1416-4209-B1CA-811698665925">1962 - Burning ranger cabin at Three Mile Lake</a>
#
#                   </h1>
#
#                   <p>
#
#                           ranger
# cabin
# <span class='highlightedWord'>fire</span>
# winter
# interior
# lake
#                   </p>
#                   <h4><strong>Record Type:</strong> Images</h4>
#                 </div>
#               </td>
#             </tr>
#           </table>
#         </div>
#         <div class="indvResult">
#           <table>
#             <tr>
#               <td>
#                   <div class="indvImage">
#
#
#
#                         <a href="/photo
src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/011/thumbs/a03576.jpg" title="Image of 1913 - Reginald Tye and W.C. Leggett, Fire Rangers" /></a>
#
#
#
#
#
#                   </div>
#
#               </td>
#               <td>
#                 <div class="indvResultDetails">
#                   <h1>
#                         <a href="/photo/62CD7EAD-275A-4031-89F9-006792216110">1913 - Reginald Tye and W.C. Leggett, Fire Rangers</a>
#
#                   </h1>
#
#                   <p>
#
#                           Reginald Tye and W.C. Leggett, <span class='highlightedWord'>Fire</span> Rangers
#
#                           <span class='highlightedWord'>Fire</span> Rangers
#
#                           Reginald Tye (L), and W.C. Leggett (R), <span class='highlightedWord'>fire</span> rangers, 1913.
# See Reginald Tye diary in archives.
#                   </p>
#                   <h4><strong>Record Type:</strong> Images</h4>
#                 </div>
#               </td>
#             </tr>
#           </table>
#         </div>
#
#     <div class="pagination"><span class="previous_page disabled">&#8592; Previous</span> <em class="current">1</em> <a rel="next" href="/photo?page=2&amp;search_criteria=fire&amp;utf8=%E2%9C%93">2</a> <a class="next_page" rel="next" href="/photo?page=2&amp;search_criteria=fire&amp;utf8=%E2%9C%93">Next &#8594;</a></div>
#
#
#
#
#
#   </div>
#     <div class="grid_12 footer">
#       <footer>
#         The Friends of Algonquin Park, Box 248, Whitney, Ontario, Canada K0J 2M0<br>
# Charity BN/Registration #11923 4060 RR0001<br>
# © 1998 - 2020 The Friends of Algonquin Park. All Rights Reserved. <br>
#
# Use or reproduction of all text, images, and other materials on this website is prohibited, without prior permission from The Friends of Algonquin Park.
#
# <!--CrazyEgg-->
#
# <script type="text/javascript">
# setTimeout(function(){var a=document.createElement("script");
# var b=document.getElementsByTagName("script")[0];
# a.src=document.location.protocol+"//script.crazyegg.com/pages/scripts/0010/3186.js?"+Math.floor(new Date().getTime()/3600000);
# a.async=true;a.type="text/javascript";b.parentNode.insertBefore(a,b)}, 1);
# </script>
#
# <!--Google Analytics-->
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-92550587-1', 'auto');
#   ga('send', 'pageview');
#
# </script>
#       </footer>
#     </div>
# </div>
#
#
#
#
# </body>
# </html>

# %% [markdown]
# ## Understanding More html

# %% [markdown]
# At this point I invite you to go the APK Archive page we're using and right click on the page, then hit inspect. This will bring up a window on your screen that will show you the same html of the page that we see above, however on the inspect function, the html is interactive. This means that as you hover over blocks of html, the corresponding webpage element will get highlighted in blue. This is going to be important as we go forward because it is this inspect function that will allow us to pinpoint the webpage elements that we want to scrap and collect. [^2]
#
# [2] Martin Breuss, "Beautiful Soup: Build a Webscraper with Python," Real Python, https://realpython.com/beautiful-soup-web-scraper-python/

# %% [markdown]
# ## Parsing with Beautiful Soup

# %%
#import beautiful soup package that we need for parsing html, just like above but with the parser added
import requests
from bs4 import BeautifulSoup

URL = 'https://algonquinpark.pastperfectonline.com/photo?utf8=%E2%9C%93&search_criteria=fire&searchButton=Search'
response = requests.get(URL)
#Here we are making a single object to serve as our parser for the whole html of the webpage
document = BeautifulSoup(response.content, 'html.parser')
print(document.prettify())
#the print gives the raw html, just like before
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#     (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#     m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#     })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#     ga('create', 'UA-84695581-1', 'auto', 'clientTracker');
#     ga('clientTracker.send', 'pageview');
#   </script>
#   <title>
#    The Friends of Algonquin Park : Online Collections
#   </title>
#   <meta content="width=device-width" name="viewport"/>
#   <link href="https://s3.amazonaws.com/pastperfectonline/sitecontent/reset.css" media="screen" rel="stylesheet"/>
#   <link href="https://s3.amazonaws.com/pastperfectonline/sitecontent/text.css" media="screen" rel="stylesheet"/>
#   <link href="/assets/jquery-ui.min.css?body=1" media="screen" rel="stylesheet"/>
#   <link href="https://s3.amazonaws.com/pastperfectonline/sitecontent/960.css" media="screen" rel="stylesheet"/>
#   <link href="https://s3.amazonaws.com/pastperfectonline/sitecontent/pastperfect_squares.css" media="screen" rel="stylesheet"/>
#   <link href="https://s3.amazonaws.com/pastperfectonline/sitecontent/pastperfect_print.css" media="print" rel="stylesheet"/>
#   <link href="/assets/jquery.fancybox.css?body=1" media="screen" rel="stylesheet"/>
#   <script src="/assets/jquery.js?body=1">
#   </script>
#   <script src="/assets/jquery-ui.min.js?body=1">
#   </script>
#   <script src="/assets/jquery.fancybox.js?body=1">
#   </script>
#   <script src="/assets/pastperfect.js?body=1">
#   </script>
#   <meta content="Mrs2Li1H2dpkeKsIdNGrzOPpbaQLLNOXc9VsK29x0K0" name="google-site-verification"/>
#   <meta content="F52D94122EDBA3DBFD8C1E1EA934F0FE" name="msvalidate.01"/>
#   <link href="http://www.algonquinpark.on.ca/favicon.ico" rel="icon" type="image/png"/>
#   <meta content="authenticity_token" name="csrf-param"/>
#   <meta content="ZAbjLHP5aoNj99WNSY1IB9mDo5CgIvV8cqQbzVKFYW8=" name="csrf-token"/>
#   <style>
#    body {
# background-color:#ffffff;
# }
#
# .container_12{
# box-shadow:0 0 .9em #333333;
# }
#
# .header{
# padding:5px 0;
# background-color:#7e8768;
# text-align:center;
# }
#
# footer {
# background-color:#576b66;
# color:#ffffff;
# font-size:12px;
# }
#
# .topNav a {
# background-color:#5d684e;
# border-color:#5d684e;
# border-radius:0;
# color:#ffffff;
# font-weight:bold;
# font-size:14px;
# }
#
# .topNav a:hover {
# background-color:#93A174;
# border-color:#93A174;
# color:#353E70;
# }
#
# .leftNav a {
# background-color:#5d684e;
# border-color:#5d684e;
# border-radius:0;
# color:#ffffff;
# font-weight:bold;
# }
#
# .leftNav a:hover {
# background-color:#93A174;
# border-color:#93A174;
# color:#353E70;
# }
#
# .topSearchArea input[type=submit] {
# background-color:#5d684e;
# border-color:#5d684e;
# color:#ffffff;
# }
#
# .topSearchArea input[type=submit]:hover {
# background-color:#93A174;
# border-color:#93A174;
# color:#353E70;
# }
#
# .advancedSearchArea input[type=submit] {
# background-color:#5d684e;
# border-color:#5d684e;
# color:#ffffff;
# }
#
# .advancedSearchArea input[type=submit]:hover {
# background-color:#93A174;
# border-color:#93A174;
# color:#353E70;
# }
#
# .vocabulary_letters a, .vocabulary_words_div a {
# color:#B01E24;
# }
#
# .vocabulary_letters a:hover, .vocabulary_words_div a:hover {
# color:#B01E24;
# }
#
# a#randomImagesFooterLink {
# font-size: 16px;
# font-weight: bold;
# }
#
# a {
# color:#B01E24;
# text-decoration: underline;
# }
#
# a:hover {
# color:#B01E24;
# text-decoration: none;
# }
#
# .indvResultDetails h1 {
# line-height:20px;
# }
#
# .indvResultDetails a {
# color:#5d684e;
# font-size:20px;
# }
#
# .indvResultDetails a:hover {
# color:#93A174;
# }
#
# .indvImage:hover {
# border: solid 2px #93A174;
# }
#
# .largeImage:hover {
# border: solid 2px #93A174;
# }
#
# img.indvImage,img.indvImage:hover{
# border:none;
# cursor:default;
# }
#
# .highlightedWord {
# color:#353E70;
# font-weight:bold;
# }
#
# .searchResultTitle Number {
# color:#353E70;
# }
#
# @media screen and (min-width:640px){
# .topNav{
# background-color:#5d684e;
# }
# .topNav li{
# margin:0;
# }
# .topNav a,.topNav a:hover{
# border-left-color:#ffffff;
# margin-left:-4px;
# }
# .topNav li:first-child a{
# border-left-color:#5d684e;
# }
# .activities{
# margin-left:-10px;
# }
# }
#
# @media screen and (max-width:640px){
# .activities{
# display:none;
# }
# }
#
#       .floatRight{
#         float:right;
#       }
#
#       .floatLeft{
#         float:left;
#       }
#
#       .fullWidth{
#         width:100%;
#       }
#   </style>
#  </head>
#  <body>
#   <div class="container_12">
#    <div class="skipnav">
#     <a href="#maincontent">
#      Skip to content
#     </a>
#    </div>
#    <header>
#     <div class="grid_12 header">
#      <a href="http://www.algonquinpark.on.ca/" target="_blank">
#       <img alt="Museum logo" src="https://s3.amazonaws.com/pastperfectonline/museumlogos/logos/552/original/logo.jpg?1474917706"/>
#       <img alt="Logo text" src="https://s3.amazonaws.com/pastperfectonline/museumlogos/images/1332/original/logo_text.jpg?1474917953"/>
#      </a>
#     </div>
#    </header>
#    <div class="grid_2 leftNav">
#     <nav>
#      <ul>
#       <li id="navCustom">
#        <a class="button" href="http://www.algonquinpark.on.ca/">
#         Algonquin Park
#        </a>
#       </li>
#       <li id="navLanding">
#        <a class="button" href="/">
#         Archives Online
#        </a>
#       </li>
#       <li id="navKeyword">
#        <a class="button" href="/search">
#         Keyword Search
#        </a>
#       </li>
#       <li id="navAdvanced">
#        <a class="button" href="/advancedsearch">
#         Advanced Search
#        </a>
#       </li>
#       <li id="navRandom">
#        <a class="button" href="/randomimages">
#         Random Images
#        </a>
#       </li>
#       <li id="navArchives">
#        <a class="button" href="/archive">
#         Archives
#        </a>
#       </li>
#       <li id="navPhotos">
#        <a class="button" href="/photo">
#         Images
#        </a>
#       </li>
#       <li id="navLibrary">
#        <a class="button" href="/library">
#         Library
#        </a>
#       </li>
#       <li id="navObjects">
#        <a class="button" href="/webobject">
#         Artifacts
#        </a>
#       </li>
#      </ul>
#     </nav>
#    </div>
#    <div class="grid_10" id="maincontent">
#     <form accept-charset="UTF-8" action="photo" method="get">
#      <div style="margin:0;padding:0;display:inline">
#       <input name="utf8" type="hidden" value="✓"/>
#      </div>
#      <div class="topSearchArea">
#       <input aria-label="Enter Search Criteria" class="search_box" id="search_criteria" name="search_criteria" placeholder="Enter Photo Search Criteria Here" type="text" value="fire"/>
#       <input name="searchButton" type="submit" value="Search"/>
#       <br/>
#       <input aria-label="Items with Images Only" id="only_images" name="only_images" type="checkbox"/>
#       Items with Images Only
#       <p>
#        <strong>
#         Search Hints:
#        </strong>
#        To search by phrase wrap your criteria in quotes. ex: "Find me"
#       </p>
#      </div>
#     </form>
#     <h1 class="searchResultTitle">
#      <number>
#       200
#      </number>
#      results found. Records searched: 6904
#     </h1>
#     <div class="indvResult">
#      <table>
#       <tr>
#        <td>
#         <div class="indvImage">
#          <a href="/photo/A833C586-B138-4061-B0E3-785438375747">
#           <img alt="Image of ca. 1926 - Camp Tanamakoon" src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/017/thumbs/a06688.jpg" title="Image of ca. 1926 - Camp Tanamakoon"/>
#          </a>
#         </div>
#        </td>
#        <td>
#         <div class="indvResultDetails">
#          <h1>
#           <a href="/photo/A833C586-B138-4061-B0E3-785438375747">
#            ca. 1926 - Camp Tanamakoon
#           </a>
#          </h1>
#          <p>
#           Camp Tanamakoon
# campers
# lunch
#           <span class="highlightedWord">
#            fire
#           </span>
#           recreation
#
#                           Camp Tanamakoon "Chickasaw" campers staging a lunch
#           <span class="highlightedWord">
#            fire
#           </span>
#           .
#          </p>
#          <h4>
#           <strong>
#            Record Type:
#           </strong>
#           Images
#          </h4>
#         </div>
#        </td>
#       </tr>
#      </table>
#     </div>
#     <div class="indvResult">
#      <table>
#       <tr>
#        <td>
#         <div class="indvImage">
#          <a href="/photo/3A77376A-D1C7-4669-BA14-882771243770">
#           <img alt="Image of 1977 - Barron Canyon Fire" src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/012/thumbs/a03750.jpg" title="Image of 1977 - Barron Canyon Fire"/>
#          </a>
#         </div>
#        </td>
#        <td>
#         <div class="indvResultDetails">
#          <h1>
#           <a href="/photo/3A77376A-D1C7-4669-BA14-882771243770">
#            1977 - Barron Canyon Fire
#           </a>
#          </h1>
#          <p>
#           Barron Canyon
#           <span class="highlightedWord">
#            Fire
#           </span>
#           <span class="highlightedWord">
#            Fire
#           </span>
#           Barron Canyon
#           <span class="highlightedWord">
#            Fire
#           </span>
#           , #28, 21/5/77, ground
#           <span class="highlightedWord">
#            fire
#           </span>
#           , burned 10 acres. This photo was taken a couple of
#          </p>
#          <h4>
#           <strong>
#            Record Type:
#           </strong>
#           Images
#          </h4>
#         </div>
#        </td>
#       </tr>
#      </table>
#     </div>
#     <div class="indvResult">
#      <table>
#       <tr>
#        <td>
#         <div class="indvImage">
#          <a href="/photo/22902A1C-BC67-465F-8436-068155738233">
#           <img alt="Image of September 11, 1944 - Ne-ow-notin Island, Cedar Lake" src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/017/thumbs/a06649.jpg" title="Image of September 11, 1944 - Ne-ow-notin Island, Cedar Lake"/>
#          </a>
#         </div>
#        </td>
#        <td>
#         <div class="indvResultDetails">
#          <h1>
#           <a href="/photo/22902A1C-BC67-465F-8436-068155738233">
#            September 11, 1944 - Ne-ow-notin Island, Cedar Lake
#           </a>
#          </h1>
#          <p>
#           "View of the interior at night.  The illumination being 3 oil lamps on the mantle and the
#           <span class="highlightedWord">
#            fire
#           </span>
#           . Exp
#          </p>
#          <h4>
#           <strong>
#            Record Type:
#           </strong>
#           Images
#          </h4>
#         </div>
#        </td>
#       </tr>
#      </table>
#     </div>
#     <div class="indvResult">
#      <table>
#       <tr>
#        <td>
#         <div class="indvImage">
#          <a href="/photo/BDFAF8BB-F663-4AC6-8EB7-401499233125">
#           <img alt="Image of 1916. - Rose Thomas in front of the hill in front of Canoe Lake Station, December 20, 1916." src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/005/thumbs/a00042.jpg" title="Image of 1916. - Rose Thomas in front of the hill in front of Canoe Lake Station, December 20, 1916."/>
#          </a>
#         </div>
#        </td>
#        <td>
#         <div class="indvResultDetails">
#          <h1>
#           <a href="/photo/BDFAF8BB-F663-4AC6-8EB7-401499233125">
#            1916. - Rose Thomas in front of the hill in front of Canoe Lake Station, December 20, 1916.
#           </a>
#          </h1>
#          <p>
#           final blow to the hill was a
#           <span class="highlightedWord">
#            fire
#           </span>
#           started by a Grand Trunk Railway steam locomotive, which burned the
#          </p>
#          <h4>
#           <strong>
#            Record Type:
#           </strong>
#           Images
#          </h4>
#         </div>
#        </td>
#       </tr>
#      </table>
#     </div>
#     <div class="indvResult">
#      <table>
#       <tr>
#        <td>
#         <div class="indvImage">
#          <a href="/photo/27F1913B-3F38-4D87-B1EB-360057568911">
#           <img alt="Image of 1922 - Lake Louisa" src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/007/thumbs/a01224.jpg" title="Image of 1922 - Lake Louisa"/>
#          </a>
#         </div>
#        </td>
#        <td>
#         <div class="indvResultDetails">
#          <h1>
#           <a href="/photo/27F1913B-3F38-4D87-B1EB-360057568911">
#            1922 - Lake Louisa
#           </a>
#          </h1>
#          <p>
#           Fish
# Fishing
# Camp
#           <span class="highlightedWord">
#            Fire
#           </span>
#           Cooking
# Camping
#
#                           standing around a
#           <span class="highlightedWord">
#            fire
#           </span>
#           with cooking utensils.
#          </p>
#          <h4>
#           <strong>
#            Record Type:
#           </strong>
#           Images
#          </h4>
#         </div>
#        </td>
#       </tr>
#      </table>
#     </div>
#     <div class="indvResult">
#      <table>
#       <tr>
#        <td>
#         <div class="indvImage">
#          <a href="/photo/44C42E50-B3E3-407C-9DA6-540023428341">
#           <img alt="Image of 1927 - Tower for drying fire hose, Brule Lake." src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/010/thumbs/a02805.jpg" title="Image of 1927 - Tower for drying fire hose, Brule Lake."/>
#          </a>
#         </div>
#        </td>
#        <td>
#         <div class="indvResultDetails">
#          <h1>
#           <a href="/photo/44C42E50-B3E3-407C-9DA6-540023428341">
#            1927 - Tower for drying fire hose, Brule Lake.
#           </a>
#          </h1>
#          <p>
#           Tower for drying
#           <span class="highlightedWord">
#            fire
#           </span>
#           hose, Brule Lake.
#           <span class="highlightedWord">
#            fire
#           </span>
#           prevention
# towers
#
#                           Two men on top of tower used for drying
#           <span class="highlightedWord">
#            fire
#           </span>
#           hose.
#          </p>
#          <h4>
#           <strong>
#            Record Type:
#           </strong>
#           Images
#          </h4>
#         </div>
#        </td>
#       </tr>
#      </table>
#     </div>
#     <div class="indvResult">
#      <table>
#       <tr>
#        <td>
#         <div class="indvImage">
#          <a href="/photo/17C297A7-29A6-46D8-96F7-013333644848">
#           <img alt="Image of 1895 - W.S. Cranston's Survey Camp, No. 1, Cache Lake." src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/005/thumbs/a00148.jpg" title="Image of 1895 - W.S. Cranston's Survey Camp, No. 1, Cache Lake."/>
#          </a>
#         </div>
#        </td>
#        <td>
#         <div class="indvResultDetails">
#          <h1>
#           <a href="/photo/17C297A7-29A6-46D8-96F7-013333644848">
#            1895 - W.S. Cranston's Survey Camp, No. 1, Cache Lake.
#           </a>
#          </h1>
#          <p>
#           Six men sitting around camp with three tents, and a
#           <span class="highlightedWord">
#            fire
#           </span>
#           blazing in summer or early fall. Names of
#          </p>
#          <h4>
#           <strong>
#            Record Type:
#           </strong>
#           Images
#          </h4>
#         </div>
#        </td>
#       </tr>
#      </table>
#     </div>
#     <div class="indvResult">
#      <table>
#       <tr>
#        <td>
#         <div class="indvImage">
#          <a href="/photo/9CB8D6F7-1FB6-47FE-9CAD-176017211400">
#           <img alt="Image of 19- - Burning brush on raft due to fire hazard - Smoke Lake." src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/007/thumbs/a01432.jpg" title="Image of 19- - Burning brush on raft due to fire hazard - Smoke Lake."/>
#          </a>
#         </div>
#        </td>
#        <td>
#         <div class="indvResultDetails">
#          <h1>
#           <a href="/photo/9CB8D6F7-1FB6-47FE-9CAD-176017211400">
#            19- - Burning brush on raft due to fire hazard - Smoke Lake.
#           </a>
#          </h1>
#          <p>
#           Burning brush on raft due to
#           <span class="highlightedWord">
#            fire
#           </span>
#           hazard - Smoke Lake.
#           <span class="highlightedWord">
#            fire
#           </span>
#           R. Norman peering out from behind large rock outcropping while
#           <span class="highlightedWord">
#            fire
#           </span>
#           on a raft burns in left side of
#          </p>
#          <h4>
#           <strong>
#            Record Type:
#           </strong>
#           Images
#          </h4>
#         </div>
#        </td>
#       </tr>
#      </table>
#     </div>
#     <div class="indvResult">
#      <table>
#       <tr>
#        <td>
#         <div class="indvImage">
#          <a href="/photo/0CD9724C-81FD-40E9-B2D0-953588051610">
#           <img alt="Image of Camp Tanamakoon" src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/017/thumbs/a06777.jpg" title="Image of Camp Tanamakoon"/>
#          </a>
#         </div>
#        </td>
#        <td>
#         <div class="indvResultDetails">
#          <h1>
#           <a href="/photo/0CD9724C-81FD-40E9-B2D0-953588051610">
#            Camp Tanamakoon
#           </a>
#          </h1>
#          <p>
#           canoe
# canoe trip
# Camp Tanamakoon
# campsite
#           <span class="highlightedWord">
#            fire
#           </span>
#           recreation
#
#                           Relaxing around the campsite and
#           <span class="highlightedWord">
#            fire
#           </span>
#           on a Camp Tanamakoon canoe trip.
#          </p>
#          <h4>
#           <strong>
#            Record Type:
#           </strong>
#           Images
#          </h4>
#         </div>
#        </td>
#       </tr>
#      </table>
#     </div>
#     <div class="indvResult">
#      <table>
#       <tr>
#        <td>
#         <div class="indvImage">
#          <a href="/photo/6F8681B6-85DB-44E7-8AC4-343394510760">
#           <img alt="Image of ca. 1930 - Jack Burchat at Kioshkokwi dam." src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/010/thumbs/a03047.jpg" title="Image of ca. 1930 - Jack Burchat at Kioshkokwi dam."/>
#          </a>
#         </div>
#        </td>
#        <td>
#         <div class="indvResultDetails">
#          <h1>
#           <a href="/photo/6F8681B6-85DB-44E7-8AC4-343394510760">
#            ca. 1930 - Jack Burchat at Kioshkokwi dam.
#           </a>
#          </h1>
#          <p>
#           <span class="highlightedWord">
#            fire
#           </span>
#           rangers
# rangers
# dams
#          </p>
#          <h4>
#           <strong>
#            Record Type:
#           </strong>
#           Images
#          </h4>
#         </div>
#        </td>
#       </tr>
#      </table>
#     </div>
#     <div class="indvResult">
#      <table>
#       <tr>
#        <td>
#         <div class="indvImage">
#          <a href="/photo/2575DFA8-F8FD-45B7-8E27-100375370539">
#           <img alt="Image of 1962 - Burning the ranger cabin at Maple Lake, March 20, 1962." src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/015/thumbs/a05797.jpg" title="Image of 1962 - Burning the ranger cabin at Maple Lake, March 20, 1962."/>
#          </a>
#         </div>
#        </td>
#        <td>
#         <div class="indvResultDetails">
#          <h1>
#           <a href="/photo/2575DFA8-F8FD-45B7-8E27-100375370539">
#            1962 - Burning the ranger cabin at Maple Lake, March 20, 1962.
#           </a>
#          </h1>
#          <p>
#           ranger
# log cabin
# shelter hut
# park buildings
#           <span class="highlightedWord">
#            fire
#           </span>
#           Maple Lake Cabin
#          </p>
#          <h4>
#           <strong>
#            Record Type:
#           </strong>
#           Images
#          </h4>
#         </div>
#        </td>
#       </tr>
#      </table>
#     </div>
#     <div class="indvResult">
#      <table>
#       <tr>
#        <td>
#         <div class="indvImage">
#          <a href="/photo/C183DEB5-961C-411B-BB49-192064076493">
#           <img alt="Image of 1936 - Climbing Fire Tower on White Lake." src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/008/thumbs/a01535.jpg" title="Image of 1936 - Climbing Fire Tower on White Lake."/>
#          </a>
#         </div>
#        </td>
#        <td>
#         <div class="indvResultDetails">
#          <h1>
#           <a href="/photo/C183DEB5-961C-411B-BB49-192064076493">
#            1936 - Climbing Fire Tower on White Lake.
#           </a>
#          </h1>
#          <p>
#           Climbing
#           <span class="highlightedWord">
#            Fire
#           </span>
#           Tower on White Lake.
#           <span class="highlightedWord">
#            fire
#           </span>
#           towers
#
#                           Two people climbing the steel
#           <span class="highlightedWord">
#            fire
#           </span>
#           tower at White Lake.
#          </p>
#          <h4>
#           <strong>
#            Record Type:
#           </strong>
#           Images
#          </h4>
#         </div>
#        </td>
#       </tr>
#      </table>
#     </div>
#     <div class="indvResult">
#      <table>
#       <tr>
#        <td>
#         <div class="indvImage">
#          <a href="/photo/62513960-7E7F-4D1C-9350-578632334460">
#           <img alt="Image of ca. 1957 - Fire, Barron Twp." src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/015/thumbs/a05521.jpg" title="Image of ca. 1957 - Fire, Barron Twp."/>
#          </a>
#         </div>
#        </td>
#        <td>
#         <div class="indvResultDetails">
#          <h1>
#           <a href="/photo/62513960-7E7F-4D1C-9350-578632334460">
#            ca. 1957 - Fire, Barron Twp.
#           </a>
#          </h1>
#          <p>
#           <span class="highlightedWord">
#            Fire
#           </span>
#           , Barron Twp.
#
#                           aerial view
#           <span class="highlightedWord">
#            fire
#           </span>
#           forest
#           <span class="highlightedWord">
#            fire
#           </span>
#           natural disturbance
#           <span class="highlightedWord">
#            Fire
#           </span>
#           , Barron Township, c. 1957.
#          </p>
#          <h4>
#           <strong>
#            Record Type:
#           </strong>
#           Images
#          </h4>
#         </div>
#        </td>
#       </tr>
#      </table>
#     </div>
#     <div class="indvResult">
#      <table>
#       <tr>
#        <td>
#         <div class="indvImage">
#          <a href="/photo/F24B2C3D-6EEC-41B3-89F7-387294838010">
#           <img alt="Image of October 28, 1970 - The cooking utensils in the Camboose shanty" src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/006/thumbs/a00636.jpg" title="Image of October 28, 1970 - The cooking utensils in the Camboose shanty"/>
#          </a>
#         </div>
#        </td>
#        <td>
#         <div class="indvResultDetails">
#          <h1>
#           <a href="/photo/F24B2C3D-6EEC-41B3-89F7-387294838010">
#            October 28, 1970 - The cooking utensils in the Camboose shanty
#           </a>
#          </h1>
#          <p>
#           Detail of cooking equipment and open
#           <span class="highlightedWord">
#            fire
#           </span>
#           pit in the Camboose shanty
#          </p>
#          <h4>
#           <strong>
#            Record Type:
#           </strong>
#           Images
#          </h4>
#         </div>
#        </td>
#       </tr>
#      </table>
#     </div>
#     <div class="indvResult">
#      <table>
#       <tr>
#        <td>
#         <div class="indvImage">
#          <a href="/photo/DEABEE04-1842-4ECB-98A4-279637468001">
#           <img alt="Image of 1927?, 1923-24 - Fire rangers, Max Hubert and Aubrey Dunne." src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/005/thumbs/a00189.jpg" title="Image of 1927?, 1923-24 - Fire rangers, Max Hubert and Aubrey Dunne."/>
#          </a>
#         </div>
#        </td>
#        <td>
#         <div class="indvResultDetails">
#          <h1>
#           <a href="/photo/DEABEE04-1842-4ECB-98A4-279637468001">
#            1927?, 1923-24 - Fire rangers, Max Hubert and Aubrey Dunne.
#           </a>
#          </h1>
#          <p>
#           <span class="highlightedWord">
#            Fire
#           </span>
#           rangers, Max Hubert and Aubrey Dunne.
#           <span class="highlightedWord">
#            Fire
#           </span>
#           Rangers
#          </p>
#          <h4>
#           <strong>
#            Record Type:
#           </strong>
#           Images
#          </h4>
#         </div>
#        </td>
#       </tr>
#      </table>
#     </div>
#     <div class="indvResult">
#      <table>
#       <tr>
#        <td>
#         <div class="indvImage">
#          <a href="/photo/D377651C-FC10-4E43-A099-196169369278">
#           <img alt="Image of 1958 - Fire tower, Crow Lake." src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/017/thumbs/a01933.jpg" title="Image of 1958 - Fire tower, Crow Lake."/>
#          </a>
#         </div>
#        </td>
#        <td>
#         <div class="indvResultDetails">
#          <h1>
#           <a href="/photo/D377651C-FC10-4E43-A099-196169369278">
#            1958 - Fire tower, Crow Lake.
#           </a>
#          </h1>
#          <p>
#           <span class="highlightedWord">
#            Fire
#           </span>
#           tower, Crow Lake.
#           <span class="highlightedWord">
#            fire
#           </span>
#           towers
#
#                           Looking up at the Crow Lake
#           <span class="highlightedWord">
#            fire
#           </span>
#           tower.
#          </p>
#          <h4>
#           <strong>
#            Record Type:
#           </strong>
#           Images
#          </h4>
#         </div>
#        </td>
#       </tr>
#      </table>
#     </div>
#     <div class="indvResult">
#      <table>
#       <tr>
#        <td>
#         <div class="indvImage">
#          <a href="/photo/9332A17C-7879-4147-83BB-762584281230">
#           <img alt="Image of 1913 - Straightening the rails on the Grand Trunk Railway line Ink Lake bridge after a fire." src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/005/thumbs/a00108.jpg" title="Image of 1913 - Straightening the rails on the Grand Trunk Railway line Ink Lake bridge after a fire."/>
#          </a>
#         </div>
#        </td>
#        <td>
#         <div class="indvResultDetails">
#          <h1>
#           <a href="/photo/9332A17C-7879-4147-83BB-762584281230">
#            1913 - Straightening the rails on the Grand Trunk Railway line Ink Lake bridge after a fire.
#           </a>
#          </h1>
#          <p>
#           Straightening the rails on the Grand Trunk Railway line Ink Lake bridge after a
#           <span class="highlightedWord">
#            fire
#           </span>
#           .
#
#                           Railway
#           <span class="highlightedWord">
#            Fire
#           </span>
#           trestle
#
#                           Ink Lake was outside the west border of Algonquin Park. The bridge caught
#           <span class="highlightedWord">
#            fire
#           </span>
#           from a spark from a
#          </p>
#          <h4>
#           <strong>
#            Record Type:
#           </strong>
#           Images
#          </h4>
#         </div>
#        </td>
#       </tr>
#      </table>
#     </div>
#     <div class="indvResult">
#      <table>
#       <tr>
#        <td>
#         <div class="indvImage">
#          <a href="/photo/8B1E39F7-A7AA-4E93-A9AA-243922464639">
#           <img alt="Image of 1977 - Barron Canyon Fire" src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/012/thumbs/a03752.jpg" title="Image of 1977 - Barron Canyon Fire"/>
#          </a>
#         </div>
#        </td>
#        <td>
#         <div class="indvResultDetails">
#          <h1>
#           <a href="/photo/8B1E39F7-A7AA-4E93-A9AA-243922464639">
#            1977 - Barron Canyon Fire
#           </a>
#          </h1>
#          <p>
#           Barron Canyon
#           <span class="highlightedWord">
#            Fire
#           </span>
#           <span class="highlightedWord">
#            Fire
#           </span>
#           Barron Canyon
#           <span class="highlightedWord">
#            Fire
#           </span>
#           , #28, 21/5/77, ground
#           <span class="highlightedWord">
#            fire
#           </span>
#           , burned 10 acres. This photo was taken a couple of
#          </p>
#          <h4>
#           <strong>
#            Record Type:
#           </strong>
#           Images
#          </h4>
#         </div>
#        </td>
#       </tr>
#      </table>
#     </div>
#     <div class="indvResult">
#      <table>
#       <tr>
#        <td>
#         <div class="indvImage">
#          <a href="/photo/3D1AB6F9-AB72-48F3-8C2D-535311638438">
#           <img alt="Image of Big Trout fire tower." src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/010/thumbs/a02737.jpg" title="Image of Big Trout fire tower."/>
#          </a>
#         </div>
#        </td>
#        <td>
#         <div class="indvResultDetails">
#          <h1>
#           <a href="/photo/3D1AB6F9-AB72-48F3-8C2D-535311638438">
#            Big Trout fire tower.
#           </a>
#          </h1>
#          <p>
#           Big Trout
#           <span class="highlightedWord">
#            fire
#           </span>
#           tower.
#           <span class="highlightedWord">
#            fire
#           </span>
#           tower
#           <span class="highlightedWord">
#            fire
#           </span>
#           prevention
# towers
#           <span class="highlightedWord">
#            Fire
#           </span>
#           tower at Big Trout Lake.
#          </p>
#          <h4>
#           <strong>
#            Record Type:
#           </strong>
#           Images
#          </h4>
#         </div>
#        </td>
#       </tr>
#      </table>
#     </div>
#     <div class="indvResult">
#      <table>
#       <tr>
#        <td>
#         <div class="indvImage">
#          <a href="/photo/C354CD3A-085C-4EF6-B932-427391365878">
#           <img alt="Image of Ontario Fire Protection Railway Car" src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/006/thumbs/a00505.jpg" title="Image of Ontario Fire Protection Railway Car"/>
#          </a>
#         </div>
#        </td>
#        <td>
#         <div class="indvResultDetails">
#          <h1>
#           <a href="/photo/C354CD3A-085C-4EF6-B932-427391365878">
#            Ontario Fire Protection Railway Car
#           </a>
#          </h1>
#          <p>
#           Ontario
#           <span class="highlightedWord">
#            Fire
#           </span>
#           Protection Railway Car
#
#                           Railway
#           <span class="highlightedWord">
#            Fire
#           </span>
#           Man standing beside railway car and pump used during
#           <span class="highlightedWord">
#            fire
#           </span>
#           protection by CNR
#          </p>
#          <h4>
#           <strong>
#            Record Type:
#           </strong>
#           Images
#          </h4>
#         </div>
#        </td>
#       </tr>
#      </table>
#     </div>
#     <div class="indvResult">
#      <table>
#       <tr>
#        <td>
#         <div class="indvImage">
#          <a href="/photo/F32853E4-F0E4-41B0-ABE0-804916978768">
#           <img alt="Image of Joseph Gauthier, Fire Ranger." src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/005/thumbs/a00049.jpg" title="Image of Joseph Gauthier, Fire Ranger."/>
#          </a>
#         </div>
#        </td>
#        <td>
#         <div class="indvResultDetails">
#          <h1>
#           <a href="/photo/F32853E4-F0E4-41B0-ABE0-804916978768">
#            Joseph Gauthier, Fire Ranger.
#           </a>
#          </h1>
#          <p>
#           Joseph Gauthier,
#           <span class="highlightedWord">
#            Fire
#           </span>
#           Ranger.
#           <span class="highlightedWord">
#            Fire
#           </span>
#           ranger
# Park Ranger
#
#                           The "Grand Old Man of Catfish Lake". At one time summer
#           <span class="highlightedWord">
#            fire
#           </span>
#           rangers were stationed all through the
#          </p>
#          <h4>
#           <strong>
#            Record Type:
#           </strong>
#           Images
#          </h4>
#         </div>
#        </td>
#       </tr>
#      </table>
#     </div>
#     <div class="indvResult">
#      <table>
#       <tr>
#        <td>
#         <div class="indvImage">
#          <a href="/photo/3767316B-24CB-44AC-B745-347843925366">
#           <img alt="Image of 1932 - George Holmberg and Mr. Shields with a fishing party from New York at campsite near Lake Opeongo." src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/005/thumbs/a00099.jpg" title="Image of 1932 - George Holmberg and Mr. Shields with a fishing party from New York at campsite near Lake Opeongo."/>
#          </a>
#         </div>
#        </td>
#        <td>
#         <div class="indvResultDetails">
#          <h1>
#           <a href="/photo/3767316B-24CB-44AC-B745-347843925366">
#            1932 - George Holmberg and Mr. Shields with a fishing party from New York at campsite near Lake Opeongo.
#           </a>
#          </h1>
#          <p>
#           Six men standing around a
#           <span class="highlightedWord">
#            fire
#           </span>
#           in the sunshine. George Holmberg is on the left and Mr. Shields, a
#          </p>
#          <h4>
#           <strong>
#            Record Type:
#           </strong>
#           Images
#          </h4>
#         </div>
#        </td>
#       </tr>
#      </table>
#     </div>
#     <div class="indvResult">
#      <table>
#       <tr>
#        <td>
#         <div class="indvImage">
#          <a href="/photo/B17770DB-23C0-4898-9862-292724332037">
#           <img alt="Image of ca. 1940 - Bob Bowes at Murchison Tower." src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/010/thumbs/a02806.jpg" title="Image of ca. 1940 - Bob Bowes at Murchison Tower."/>
#          </a>
#         </div>
#        </td>
#        <td>
#         <div class="indvResultDetails">
#          <h1>
#           <a href="/photo/B17770DB-23C0-4898-9862-292724332037">
#            ca. 1940 - Bob Bowes at Murchison Tower.
#           </a>
#          </h1>
#          <p>
#           radio
#           <span class="highlightedWord">
#            fire
#           </span>
#           tower
# towers
#           <span class="highlightedWord">
#            fire
#           </span>
#           prevention
#          </p>
#          <h4>
#           <strong>
#            Record Type:
#           </strong>
#           Images
#          </h4>
#         </div>
#        </td>
#       </tr>
#      </table>
#     </div>
#     <div class="indvResult">
#      <table>
#       <tr>
#        <td>
#         <div class="indvImage">
#          <a href="/photo/9C3FE0E1-2D1A-443F-BAB4-198199584862">
#           <img alt="Image of Jack Burchat and Venus Legree, Fire Rangers." src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/010/thumbs/a03034.jpg" title="Image of Jack Burchat and Venus Legree, Fire Rangers."/>
#          </a>
#         </div>
#        </td>
#        <td>
#         <div class="indvResultDetails">
#          <h1>
#           <a href="/photo/9C3FE0E1-2D1A-443F-BAB4-198199584862">
#            Jack Burchat and Venus Legree, Fire Rangers.
#           </a>
#          </h1>
#          <p>
#           Jack Burchat and Venus Legree,
#           <span class="highlightedWord">
#            Fire
#           </span>
#           Rangers.
#           <span class="highlightedWord">
#            fire
#           </span>
#           rangers
# rangers
# fish
# camping
#          </p>
#          <h4>
#           <strong>
#            Record Type:
#           </strong>
#           Images
#          </h4>
#         </div>
#        </td>
#       </tr>
#      </table>
#     </div>
#     <div class="indvResult">
#      <table>
#       <tr>
#        <td>
#         <div class="indvImage">
#          <a href="/photo/905A819D-0988-48EF-AAF3-069811787147">
#           <img alt="Image of 1962 - Burning the ranger cabin at Shad Lake, March 19 1962." src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/015/thumbs/a05798.jpg" title="Image of 1962 - Burning the ranger cabin at Shad Lake, March 19 1962."/>
#          </a>
#         </div>
#        </td>
#        <td>
#         <div class="indvResultDetails">
#          <h1>
#           <a href="/photo/905A819D-0988-48EF-AAF3-069811787147">
#            1962 - Burning the ranger cabin at Shad Lake, March 19 1962.
#           </a>
#          </h1>
#          <p>
#           Shad Lake Cabin
# log cabin
# ranger
# park buildings
#           <span class="highlightedWord">
#            fire
#           </span>
#           shelter hut
#          </p>
#          <h4>
#           <strong>
#            Record Type:
#           </strong>
#           Images
#          </h4>
#         </div>
#        </td>
#       </tr>
#      </table>
#     </div>
#     <div class="indvResult">
#      <table>
#       <tr>
#        <td>
#         <div class="indvImage">
#          <a href="/photo/355E43EB-1B4D-4326-BC65-304579941593">
#           <img alt="Image of 1933 - Burning Brush" src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/018/thumbs/a04220.jpg" title="Image of 1933 - Burning Brush"/>
#          </a>
#         </div>
#        </td>
#        <td>
#         <div class="indvResultDetails">
#          <h1>
#           <a href="/photo/355E43EB-1B4D-4326-BC65-304579941593">
#            1933 - Burning Brush
#           </a>
#          </h1>
#          <p>
#           Interior
#           <span class="highlightedWord">
#            Fire
#           </span>
#           Camping
#          </p>
#          <h4>
#           <strong>
#            Record Type:
#           </strong>
#           Images
#          </h4>
#         </div>
#        </td>
#       </tr>
#      </table>
#     </div>
#     <div class="indvResult">
#      <table>
#       <tr>
#        <td>
#         <div class="indvImage">
#          <a href="/photo/93DC9A0E-4ED3-4145-8A8B-185533409342">
#           <img alt="Image of 1918 - Forest Fire sign" src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/016/thumbs/a05997.jpg" title="Image of 1918 - Forest Fire sign"/>
#          </a>
#         </div>
#        </td>
#        <td>
#         <div class="indvResultDetails">
#          <h1>
#           <a href="/photo/93DC9A0E-4ED3-4145-8A8B-185533409342">
#            1918 - Forest Fire sign
#           </a>
#          </h1>
#          <p>
#           Forest
#           <span class="highlightedWord">
#            Fire
#           </span>
#           sign
#
#                           Forest
#           <span class="highlightedWord">
#            fire
#           </span>
#           sign, 1918.
#          </p>
#          <h4>
#           <strong>
#            Record Type:
#           </strong>
#           Images
#          </h4>
#         </div>
#        </td>
#       </tr>
#      </table>
#     </div>
#     <div class="indvResult">
#      <table>
#       <tr>
#        <td>
#         <div class="indvImage">
#          <a href="/photo/AB4047BC-CF8D-4DCB-A9C0-793755596830">
#           <img alt="Image of Wooden fire tower" src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/017/thumbs/a06444.jpg" title="Image of Wooden fire tower"/>
#          </a>
#         </div>
#        </td>
#        <td>
#         <div class="indvResultDetails">
#          <h1>
#           <a href="/photo/AB4047BC-CF8D-4DCB-A9C0-793755596830">
#            Wooden fire tower
#           </a>
#          </h1>
#          <p>
#           Wooden
#           <span class="highlightedWord">
#            fire
#           </span>
#           tower
#           <span class="highlightedWord">
#            fire
#           </span>
#           <span class="highlightedWord">
#            fire
#           </span>
#           tower
# tower
#           <span class="highlightedWord">
#            fire
#           </span>
#           prevention
#
#                           Wooden
#           <span class="highlightedWord">
#            fire
#           </span>
#           tower, Location ?
#          </p>
#          <h4>
#           <strong>
#            Record Type:
#           </strong>
#           Images
#          </h4>
#         </div>
#        </td>
#       </tr>
#      </table>
#     </div>
#     <div class="indvResult">
#      <table>
#       <tr>
#        <td>
#         <div class="indvImage">
#          <a href="/photo/CCA73CF9-0FAA-43C1-B160-561245594166">
#           <img alt="Image of Jack Burchat." src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/010/thumbs/a03039.jpg" title="Image of Jack Burchat."/>
#          </a>
#         </div>
#        </td>
#        <td>
#         <div class="indvResultDetails">
#          <h1>
#           <a href="/photo/CCA73CF9-0FAA-43C1-B160-561245594166">
#            Jack Burchat.
#           </a>
#          </h1>
#          <p>
#           railway
# stations
#           <span class="highlightedWord">
#            fire
#           </span>
#           rangers
# rangers
#          </p>
#          <h4>
#           <strong>
#            Record Type:
#           </strong>
#           Images
#          </h4>
#         </div>
#        </td>
#       </tr>
#      </table>
#     </div>
#     <div class="indvResult">
#      <table>
#       <tr>
#        <td>
#         <div class="indvImage">
#          <a href="/photo/BE6AA5F0-54C4-47D0-8ED5-444666743803">
#           <img alt="Image of ca. 1922 - Mowat Lodge, Fireplace." src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/007/thumbs/a01016.jpg" title="Image of ca. 1922 - Mowat Lodge, Fireplace."/>
#          </a>
#         </div>
#        </td>
#        <td>
#         <div class="indvResultDetails">
#          <h1>
#           <a href="/photo/BE6AA5F0-54C4-47D0-8ED5-444666743803">
#            ca. 1922 - Mowat Lodge, Fireplace.
#           </a>
#          </h1>
#          <p>
#           Annie Fraser sitting in a rocking chair in front of the
#           <span class="highlightedWord">
#            fire
#           </span>
#           . Second Lodge(?)
#          </p>
#          <h4>
#           <strong>
#            Record Type:
#           </strong>
#           Images
#          </h4>
#         </div>
#        </td>
#       </tr>
#      </table>
#     </div>
#     <div class="indvResult">
#      <table>
#       <tr>
#        <td>
#         <div class="indvImage">
#          <a href="/photo/15DF7695-21F7-4D71-834D-570163084810">
#           <img alt="Image of 1975 - Canoe outing, Source Lake." src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/010/thumbs/a02831.jpg" title="Image of 1975 - Canoe outing, Source Lake."/>
#          </a>
#         </div>
#        </td>
#        <td>
#         <div class="indvResultDetails">
#          <h1>
#           <a href="/photo/15DF7695-21F7-4D71-834D-570163084810">
#            1975 - Canoe outing, Source Lake.
#           </a>
#          </h1>
#          <p>
#           Left to right (in uniform), Rory MacKay and Peter Ward, standing around a camp
#           <span class="highlightedWord">
#            fire
#           </span>
#           at a canoe
#          </p>
#          <h4>
#           <strong>
#            Record Type:
#           </strong>
#           Images
#          </h4>
#         </div>
#        </td>
#       </tr>
#      </table>
#     </div>
#     <div class="indvResult">
#      <table>
#       <tr>
#        <td>
#         <div class="indvImage">
#          <a href="/photo/DA182705-6CA2-47C4-B0FC-251386368711">
#           <img alt="Image of campfire, Algonquin Park" src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/015/thumbs/a05824.jpg" title="Image of campfire, Algonquin Park"/>
#          </a>
#         </div>
#        </td>
#        <td>
#         <div class="indvResultDetails">
#          <h1>
#           <a href="/photo/DA182705-6CA2-47C4-B0FC-251386368711">
#            campfire, Algonquin Park
#           </a>
#          </h1>
#          <p>
#           camp
#           <span class="highlightedWord">
#            fire
#           </span>
#           campfire
# tent
#          </p>
#          <h4>
#           <strong>
#            Record Type:
#           </strong>
#           Images
#          </h4>
#         </div>
#        </td>
#       </tr>
#      </table>
#     </div>
#     <div class="indvResult">
#      <table>
#       <tr>
#        <td>
#         <div class="indvImage">
#          <a href="/photo/A9B2676B-42AA-4FA3-80CC-362419309714">
#           <img alt="Image of 1897 - Hayes Party" src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/006/thumbs/a00598.jpg" title="Image of 1897 - Hayes Party"/>
#          </a>
#         </div>
#        </td>
#        <td>
#         <div class="indvResultDetails">
#          <h1>
#           <a href="/photo/A9B2676B-42AA-4FA3-80CC-362419309714">
#            1897 - Hayes Party
#           </a>
#          </h1>
#          <p>
#           Men sitting around a
#           <span class="highlightedWord">
#            fire
#           </span>
#           between large trees.
#          </p>
#          <h4>
#           <strong>
#            Record Type:
#           </strong>
#           Images
#          </h4>
#         </div>
#        </td>
#       </tr>
#      </table>
#     </div>
#     <div class="indvResult">
#      <table>
#       <tr>
#        <td>
#         <div class="indvImage">
#          <a href="/photo/C1F0642E-F6C8-4438-BA70-963964348865">
#           <img alt="Image of Forest Fires" src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/006/thumbs/a00972.jpg" title="Image of Forest Fires"/>
#          </a>
#         </div>
#        </td>
#        <td>
#         <div class="indvResultDetails">
#          <h1>
#           <a href="/photo/C1F0642E-F6C8-4438-BA70-963964348865">
#            Forest Fires
#           </a>
#          </h1>
#          <p>
#           forests
# fires
# water
#           <span class="highlightedWord">
#            fire
#           </span>
#           hose
#           <span class="highlightedWord">
#            fire
#           </span>
#           fighters
#
#                           One man pointing while another man uses a hose to spray water on the forest
#           <span class="highlightedWord">
#            fire
#           </span>
#           .
#          </p>
#          <h4>
#           <strong>
#            Record Type:
#           </strong>
#           Images
#          </h4>
#         </div>
#        </td>
#       </tr>
#      </table>
#     </div>
#     <div class="indvResult">
#      <table>
#       <tr>
#        <td>
#         <div class="indvImage">
#          <a href="/photo/A42BEFB5-1D04-4DFD-9515-654833516737">
#           <img alt="Image of 1934 - Table, Skymount fire tower" src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/017/thumbs/a06450.jpg" title="Image of 1934 - Table, Skymount fire tower"/>
#          </a>
#         </div>
#        </td>
#        <td>
#         <div class="indvResultDetails">
#          <h1>
#           <a href="/photo/A42BEFB5-1D04-4DFD-9515-654833516737">
#            1934 - Table, Skymount fire tower
#           </a>
#          </h1>
#          <p>
#           Table, Skymount
#           <span class="highlightedWord">
#            fire
#           </span>
#           tower
#
#                           table
#           <span class="highlightedWord">
#            fire
#           </span>
#           <span class="highlightedWord">
#            fire
#           </span>
#           tower
# tower
#           <span class="highlightedWord">
#            fire
#           </span>
#           prevention
# skymount
#
#                           Table, Skymount
#           <span class="highlightedWord">
#            fire
#           </span>
#           tower, 1934
#          </p>
#          <h4>
#           <strong>
#            Record Type:
#           </strong>
#           Images
#          </h4>
#         </div>
#        </td>
#       </tr>
#      </table>
#     </div>
#     <div class="indvResult">
#      <table>
#       <tr>
#        <td>
#         <div class="indvImage">
#          <a href="/photo/8F410F41-EBD8-4A5C-9EA6-128872860964">
#           <img alt="Image of 1977 - Barron Canyon Fire" src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/012/thumbs/a03751.jpg" title="Image of 1977 - Barron Canyon Fire"/>
#          </a>
#         </div>
#        </td>
#        <td>
#         <div class="indvResultDetails">
#          <h1>
#           <a href="/photo/8F410F41-EBD8-4A5C-9EA6-128872860964">
#            1977 - Barron Canyon Fire
#           </a>
#          </h1>
#          <p>
#           Barron Canyon
#           <span class="highlightedWord">
#            Fire
#           </span>
#           <span class="highlightedWord">
#            Fire
#           </span>
#           Barron Canyon
#           <span class="highlightedWord">
#            Fire
#           </span>
#           , #28, 21/5/77, ground
#           <span class="highlightedWord">
#            fire
#           </span>
#           , burned 10 acres. This photo was taken a couple of
#          </p>
#          <h4>
#           <strong>
#            Record Type:
#           </strong>
#           Images
#          </h4>
#         </div>
#        </td>
#       </tr>
#      </table>
#     </div>
#     <div class="indvResult">
#      <table>
#       <tr>
#        <td>
#         <div class="indvImage">
#          <a href="/photo/D239AE6B-BAD1-4314-85FA-433671284959">
# ...
#        <td>
#         <div class="indvImage">
#          <a href="/photo/4EBD1E7F-3FA1-4D50-A609-022754322723">
#           <img alt="Image of 1923 or 1927 - Aubrey Dunne." src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/005/thumbs/a00207.jpg" title="Image of 1923 or 1927 - Aubrey Dunne."/>
#          </a>
#         </div>
#        </td>
#        <td>
#         <div class="indvResultDetails">
#          <h1>
#           <a href="/photo/4EBD1E7F-3FA1-4D50-A609-022754322723">
#            1923 or 1927 - Aubrey Dunne.
#           </a>
#          </h1>
#          <p>
#           <span class="highlightedWord">
#            Fire
#           </span>
#           Ranger
# Fishing
#
#                           Aubrey Dunne standing with a fish and fishing pole. Aubrey Dunne was a
#           <span class="highlightedWord">
#            fire
#           </span>
#           ranger.
#          </p>
#          <h4>
#           <strong>
#            Record Type:
#           </strong>
#           Images
#          </h4>
#         </div>
#        </td>
#       </tr>
#      </table>
#     </div>
#     <div class="indvResult">
#      <table>
#       <tr>
#        <td>
#         <div class="indvImage">
#          <a href="/photo/F720B7E9-12E3-49C0-AC91-465331205810">
#           <img alt="Image of Jack Burchat at Kiosk." src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/010/thumbs/a03055.jpg" title="Image of Jack Burchat at Kiosk."/>
#          </a>
#         </div>
#        </td>
#        <td>
#         <div class="indvResultDetails">
#          <h1>
#           <a href="/photo/F720B7E9-12E3-49C0-AC91-465331205810">
#            Jack Burchat at Kiosk.
#           </a>
#          </h1>
#          <p>
#           <span class="highlightedWord">
#            fire
#           </span>
#           rangers
# rangers
# canoes
# canoeing
# pointer boats
#          </p>
#          <h4>
#           <strong>
#            Record Type:
#           </strong>
#           Images
#          </h4>
#         </div>
#        </td>
#       </tr>
#      </table>
#     </div>
#     <div class="indvResult">
#      <table>
#       <tr>
#        <td>
#         <div class="indvImage">
#          <a href="/photo/39CBD41E-1673-4ACE-995D-177699718219">
#           <img alt='Image of June 28, 1955. - Aerial of fire - "Treasure Island", Tea Lake, June 28, 1955.' src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/007/thumbs/a01374.jpg" title='Image of June 28, 1955. - Aerial of fire - "Treasure Island", Tea Lake, June 28, 1955.'/>
#          </a>
#         </div>
#        </td>
#        <td>
#         <div class="indvResultDetails">
#          <h1>
#           <a href="/photo/39CBD41E-1673-4ACE-995D-177699718219">
#            June 28, 1955. - Aerial of fire - "Treasure Island", Tea Lake, June 28, 1955.
#           </a>
#          </h1>
#          <p>
#           Aerial of
#           <span class="highlightedWord">
#            fire
#           </span>
#           - "Treasure Island", Tea Lake, June 28, 1955.
#
#                           A picture of an island on Tea Lake which is on
#           <span class="highlightedWord">
#            fire
#           </span>
#           .
#          </p>
#          <h4>
#           <strong>
#            Record Type:
#           </strong>
#           Images
#          </h4>
#         </div>
#        </td>
#       </tr>
#      </table>
#     </div>
#     <div class="indvResult">
#      <table>
#       <tr>
#        <td>
#         <div class="indvImage">
#          <a href="/photo/B30EC52B-6654-41CE-A7A6-344496020769">
#           <img alt="Image of 1913 - After a fire" src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/007/thumbs/a01397.jpg" title="Image of 1913 - After a fire"/>
#          </a>
#         </div>
#        </td>
#        <td>
#         <div class="indvResultDetails">
#          <h1>
#           <a href="/photo/B30EC52B-6654-41CE-A7A6-344496020769">
#            1913 - After a fire
#           </a>
#          </h1>
#          <p>
#           After a
#           <span class="highlightedWord">
#            fire
#           </span>
#           log chute
# forest
#           <span class="highlightedWord">
#            fire
#           </span>
#           Looking down a log chute into Aura Lee Lake after a forest
#           <span class="highlightedWord">
#            fire
#           </span>
#           .
#          </p>
#          <h4>
#           <strong>
#            Record Type:
#           </strong>
#           Images
#          </h4>
#         </div>
#        </td>
#       </tr>
#      </table>
#     </div>
#     <div class="indvResult">
#      <table>
#       <tr>
#        <td>
#         <div class="indvImage">
#          <a href="/photo/13AE6782-285D-460A-BB3A-241445036230">
#           <img alt="Image of After the Great Fire" src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/017/thumbs/a06411.jpg" title="Image of After the Great Fire"/>
#          </a>
#         </div>
#        </td>
#        <td>
#         <div class="indvResultDetails">
#          <h1>
#           <a href="/photo/13AE6782-285D-460A-BB3A-241445036230">
#            After the Great Fire
#           </a>
#          </h1>
#          <p>
#           After the Great
#           <span class="highlightedWord">
#            Fire
#           </span>
#           forest
#           <span class="highlightedWord">
#            fire
#           </span>
#           evacuation
# train
# railway
# transportation
#
#                           After the Great
#           <span class="highlightedWord">
#            Fire
#           </span>
#           .  Trees actually burned as residents evacuated by train.  Year (?).  Rock Lake
#          </p>
#          <h4>
#           <strong>
#            Record Type:
#           </strong>
#           Images
#          </h4>
#         </div>
#        </td>
#       </tr>
#      </table>
#     </div>
#     <div class="indvResult">
#      <table>
#       <tr>
#        <td>
#         <div class="indvImage">
#          <a href="/photo/AFD38A14-C9DC-4AB4-BAA7-591219257110">
#           <img alt="Image of Campfire" src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/003/thumbs/201416131.jpg" title="Image of Campfire"/>
#          </a>
#         </div>
#        </td>
#        <td>
#         <div class="indvResultDetails">
#          <h1>
#           <a href="/photo/AFD38A14-C9DC-4AB4-BAA7-591219257110">
#            Campfire
#           </a>
#          </h1>
#          <p>
#           camp
#           <span class="highlightedWord">
#            fire
#           </span>
#           . People can be seen sitting around it in the background. The background is very dark around
#          </p>
#          <h4>
#           <strong>
#            Record Type:
#           </strong>
#           Images
#          </h4>
#         </div>
#        </td>
#       </tr>
#      </table>
#     </div>
#     <div class="indvResult">
#      <table>
#       <tr>
#        <td>
#         <div class="indvImage">
#          <a href="/photo/15169E29-875C-4FB2-8429-987041858607">
#           <img alt="Image of 1974 - Fire tower cabin, White Trout Lake." src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/009/thumbs/a02574.jpg" title="Image of 1974 - Fire tower cabin, White Trout Lake."/>
#          </a>
#         </div>
#        </td>
#        <td>
#         <div class="indvResultDetails">
#          <h1>
#           <a href="/photo/15169E29-875C-4FB2-8429-987041858607">
#            1974 - Fire tower cabin, White Trout Lake.
#           </a>
#          </h1>
#          <p>
#           <span class="highlightedWord">
#            Fire
#           </span>
#           tower cabin, White Trout Lake.
#
#                           Bill Calvert walking toward White Trout
#           <span class="highlightedWord">
#            fire
#           </span>
#           tower cabin.
#          </p>
#          <h4>
#           <strong>
#            Record Type:
#           </strong>
#           Images
#          </h4>
#         </div>
#        </td>
#       </tr>
#      </table>
#     </div>
#     <div class="indvResult">
#      <table>
#       <tr>
#        <td>
#         <div class="indvImage">
#          <a href="/photo/C57F21A9-C85B-4367-99ED-526959310498">
#           <img alt="Image of 1977 - Barron Canyon Fire" src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/012/thumbs/a03754.jpg" title="Image of 1977 - Barron Canyon Fire"/>
#          </a>
#         </div>
#        </td>
#        <td>
#         <div class="indvResultDetails">
#          <h1>
#           <a href="/photo/C57F21A9-C85B-4367-99ED-526959310498">
#            1977 - Barron Canyon Fire
#           </a>
#          </h1>
#          <p>
#           Barron Canyon
#           <span class="highlightedWord">
#            Fire
#           </span>
#           <span class="highlightedWord">
#            Fire
#           </span>
#           Barron Canyon
#           <span class="highlightedWord">
#            Fire
#           </span>
#           , #28, 21/5/77, ground
#           <span class="highlightedWord">
#            fire
#           </span>
#           burned 10 acres. This photo was taken a couple of
#          </p>
#          <h4>
#           <strong>
#            Record Type:
#           </strong>
#           Images
#          </h4>
#         </div>
#        </td>
#       </tr>
#      </table>
#     </div>
#     <div class="indvResult">
#      <table>
#       <tr>
#        <td>
#         <div class="indvImage">
#          <a href="/photo/DB0AF497-20C9-40C1-986F-149180912300">
#           <img alt="Image of 1980 - John Simpson in front of the Dahlia ranger cabin, July 1980." src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/015/thumbs/a05684.jpg" title="Image of 1980 - John Simpson in front of the Dahlia ranger cabin, July 1980."/>
#          </a>
#         </div>
#        </td>
#        <td>
#         <div class="indvResultDetails">
#          <h1>
#           <a href="/photo/DB0AF497-20C9-40C1-986F-149180912300">
#            1980 - John Simpson in front of the Dahlia ranger cabin, July 1980.
#           </a>
#          </h1>
#          <p>
#           ranger
#           <span class="highlightedWord">
#            fire
#           </span>
#           ranger
# cabin
# park buildings
# buildings
# log cabin
#          </p>
#          <h4>
#           <strong>
#            Record Type:
#           </strong>
#           Images
#          </h4>
#         </div>
#        </td>
#       </tr>
#      </table>
#     </div>
#     <div class="indvResult">
#      <table>
#       <tr>
#        <td>
#         <div class="indvImage">
#          <a href="/photo/D72ED723-B221-4FDD-8030-300586394023">
#           <img alt="Image of 1920 - James Hyland at his Fire Ranger Cabin" src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/012/thumbs/a03714.jpg" title="Image of 1920 - James Hyland at his Fire Ranger Cabin"/>
#          </a>
#         </div>
#        </td>
#        <td>
#         <div class="indvResultDetails">
#          <h1>
#           <a href="/photo/D72ED723-B221-4FDD-8030-300586394023">
#            1920 - James Hyland at his Fire Ranger Cabin
#           </a>
#          </h1>
#          <p>
#           James Hyland at his
#           <span class="highlightedWord">
#            Fire
#           </span>
#           Ranger Cabin
#           <span class="highlightedWord">
#            Fire
#           </span>
#           Ranger
# Interior
#
#                           James Hyland at is
#           <span class="highlightedWord">
#            fire
#           </span>
#           ranger cabin, Rock Lake, 1920's.
#          </p>
#          <h4>
#           <strong>
#            Record Type:
#           </strong>
#           Images
#          </h4>
#         </div>
#        </td>
#       </tr>
#      </table>
#     </div>
#     <div class="indvResult">
#      <table>
#       <tr>
#        <td>
#         <div class="indvImage">
#          <a href="/photo/E0A6FB40-7A8B-48D7-96E0-262608449290">
#           <img alt="Image of 1943 - Algonquin Park Tower Destroyed by Flames" src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/005/thumbs/a00273.jpg" title="Image of 1943 - Algonquin Park Tower Destroyed by Flames"/>
#          </a>
#         </div>
#        </td>
#        <td>
#         <div class="indvResultDetails">
#          <h1>
#           <a href="/photo/E0A6FB40-7A8B-48D7-96E0-262608449290">
#            1943 - Algonquin Park Tower Destroyed by Flames
#           </a>
#          </h1>
#          <p>
#           Hotel
#           <span class="highlightedWord">
#            Fire
#           </span>
#           Inns
# Lodges
#          </p>
#          <h4>
#           <strong>
#            Record Type:
#           </strong>
#           Images
#          </h4>
#         </div>
#        </td>
#       </tr>
#      </table>
#     </div>
#     <div class="indvResult">
#      <table>
#       <tr>
#        <td>
#         <div class="indvImage">
#          <a href="/photo/E86069C2-B864-445A-948A-529075534824">
#           <img alt="Image of 1939 - Hauling Logs" src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/007/thumbs/a01061.jpg" title="Image of 1939 - Hauling Logs"/>
#          </a>
#         </div>
#        </td>
#        <td>
#         <div class="indvResultDetails">
#          <h1>
#           <a href="/photo/E86069C2-B864-445A-948A-529075534824">
#            1939 - Hauling Logs
#           </a>
#          </h1>
#          <p>
#           Men standing beside a tuck hauling a load of logs on a sleigh. In the "Report on Forest
#           <span class="highlightedWord">
#            Fire
#           </span>
#          </p>
#          <h4>
#           <strong>
#            Record Type:
#           </strong>
#           Images
#          </h4>
#         </div>
#        </td>
#       </tr>
#      </table>
#     </div>
#     <div class="indvResult">
#      <table>
#       <tr>
#        <td>
#         <div class="indvImage">
#          <a href="/photo/FA21732F-8DAB-4F52-9BC1-644594821835">
#           <img alt="Image of 1958 - Fire, Blue Lake." src="https://s3.amazonaws.com/pastperfectonline/images/museum_552/015/thumbs/a05520.jpg" title="Image of 1958 - Fire, Blue Lake."/>
#          </a>
#         </div>
#        </td>
#        <td>
#         <div class="indvResultDetails">
#          <h1>
#           <a href="/photo/FA21732F-8DAB-4F52-9BC1-644594821835">
#            1958 - Fire, Blue Lake.
#           </a>
#          </h1>
#          <p>
#           <span class="highlightedWord">
#            Fire
#           </span>
#           , Blue Lake.
#           <span class="highlightedWord">
#            fire
#           </span>
#           <span class="highlightedWord">
#            Fire
#           </span>
#           , Blue Lake , Bishop Township, August 4, 1958.
#          </p>
#          <h4>
#           <strong>
#            Record Type:
#           </strong>
#           Images
#          </h4>
#         </div>
#        </td>
#       </tr>
#      </table>
#     </div>
#     <div class="pagination">
#      <span class="previous_page disabled">
#       ← Previous
#      </span>
#      <em class="current">
#       1
#      </em>
#      <a href="/photo?page=2&amp;search_criteria=fire&amp;utf8=%E2%9C%93" rel="next">
#       2
#      </a>
#      <a class="next_page" href="/photo?page=2&amp;search_criteria=fire&amp;utf8=%E2%9C%93" rel="next">
#       Next →
#      </a>
#     </div>
#    </div>
#    <div class="grid_12 footer">
#     <footer>
#      The Friends of Algonquin Park, Box 248, Whitney, Ontario, Canada K0J 2M0
#      <br/>
#      Charity BN/Registration #11923 4060 RR0001
#      <br/>
#      Â© 1998 - 2020 The Friends of Algonquin Park. All Rights Reserved.
#      <br/>
#      Use or reproduction of all text, images, and other materials on this website is prohibited, without prior permission from The Friends of Algonquin Park.
#      <!--CrazyEgg-->
#      <script type="text/javascript">
#       setTimeout(function(){var a=document.createElement("script");
# var b=document.getElementsByTagName("script")[0];
# a.src=document.location.protocol+"//script.crazyegg.com/pages/scripts/0010/3186.js?"+Math.floor(new Date().getTime()/3600000);
# a.async=true;a.type="text/javascript";b.parentNode.insertBefore(a,b)}, 1);
#      </script>
#      <!--Google Analytics-->
#      <script>
#       (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-92550587-1', 'auto');
#   ga('send', 'pageview');
#      </script>
#     </footer>
#    </div>
#   </div>
#  </body>
# </html>

# %% [markdown]
# ## Finding the Links

# %%
#'h1' is html talk for headers. On the APK Archive page, all the links and titles are contained in all the 'h1'
#so, .find_all, finds all of the instances of h1 in document, which is our object for all the raw html
links = document.find_all('h1')
#For every h1 link and title popped up by document.find_all(h1), print it
for link in links: 
    print(link)
# now we have all our relevant links and their titles, with only a few extra html tags
# Out:
# <h1 class="searchResultTitle">
# <number>200</number> results found. Records searched: 6904
#       </h1>
# <h1>
# <a href="/photo/A833C586-B138-4061-B0E3-785438375747">ca. 1926 - Camp Tanamakoon</a>
# </h1>
# <h1>
# <a href="/photo/15169E29-875C-4FB2-8429-987041858607">1974 - Fire tower cabin, White Trout Lake.</a>
# </h1>
# <h1>
# <a href="/photo/C57F21A9-C85B-4367-99ED-526959310498">1977 - Barron Canyon Fire</a>
# </h1>
# <h1>
# <a href="/photo/DB0AF497-20C9-40C1-986F-149180912300">1980 - John Simpson in front of the Dahlia ranger cabin, July 1980.</a>
# </h1>
# <h1>
# <a href="/photo/D72ED723-B221-4FDD-8030-300586394023">1920 - James Hyland at his Fire Ranger Cabin</a>
# </h1>
# <h1>
# <a href="/photo/E0A6FB40-7A8B-48D7-96E0-262608449290">1943 - Algonquin Park Tower Destroyed by Flames</a>
# </h1>
# <h1>
# <a href="/photo/E86069C2-B864-445A-948A-529075534824">1939 - Hauling Logs</a>
# </h1>
# <h1>
# <a href="/photo/FA21732F-8DAB-4F52-9BC1-644594821835">1958 - Fire, Blue Lake.</a>
# </h1>

# %% [markdown]
# ## Save it all to a CSV

# %%
#At this point, we could use python to clean up links, or we could just send it to a csv and clean it there
#open- opens a csv file
#'APK_Python'- file name
#w+ allows file to be edited
# newline='' is an important thing, I'm told
csvfile = open('APK_Python.csv', 'w+', newline='')
#This actually write the file and puts stuff into the spreadsheet
writer = csv.writer(csvfile)
# This make a column header
writer.writerow(['Links'])
#This is a loop like seen above, except with the write.row function added we get all those sweet links sent to our csv file
for link in links:
        print(link)
        writer.writerow(link)
#This closes the file then we're done
csvfile.close()
# Out:
# <h1 class="searchResultTitle">
# <number>200</number> results found. Records searched: 6904
#       </h1>
# <h1>
# <a href="/photo/A833C586-B138-4061-B0E3-785438375747">ca. 1926 - Camp Tanamakoon</a>
# </h1>
# <h1>
# <a href="/photo/3A77376A-D1C7-4669-BA14-882771243770">1977 - Barron Canyon Fire</a>
# </h1>
# <h1>
# <a href="/photo/22902A1C-BC67-465F-8436-068155738233">September 11, 1944 - Ne-ow-notin Island, Cedar Lake</a>
# </h1>
# <h1>
# <a href="/photo/BDFAF8BB-F663-4AC6-8EB7-401499233125">1916. - Rose Thomas in front of the hill in front of Canoe Lake Station, December 20, 1916.</a>
# </h1>
# <h1>
# <a href="/photo/27F1913B-3F38-4D87-B1EB-360057568911">1922 - Lake Louisa</a>
# </h1>
# <h1>
# <a href="/photo/44C42E50-B3E3-407C-9DA6-540023428341">1927 - Tower for drying fire hose, Brule Lake.</a>
# </h1>
# <h1>
# <a href="/photo/17C297A7-29A6-46D8-96F7-013333644848">1895 - W.S. Cranston's Survey Camp, No. 1, Cache Lake.</a>
# </h1>
# <h1>
# <a href="/photo/9CB8D6F7-1FB6-47FE-9CAD-176017211400">19- - Burning brush on raft due to fire hazard - Smoke Lake.</a>
# </h1>
# <h1>
# <a href="/photo/0CD9724C-81FD-40E9-B2D0-953588051610">Camp Tanamakoon</a>
# </h1>
# <h1>
# <a href="/photo/6F8681B6-85DB-44E7-8AC4-343394510760">ca. 1930 - Jack Burchat at Kioshkokwi dam.</a>
# </h1>
# <h1>
# <a href="/photo/2575DFA8-F8FD-45B7-8E27-100375370539">1962 - Burning the ranger cabin at Maple Lake, March 20, 1962.</a>
# </h1>
# <h1>
# <a href="/photo/10A768FB-0B01-48F8-A67A-858252981243">Climbing Skymount Tower</a>
# </h1>
# <h1>
# <a href="/photo/46B80389-A485-4661-8CEF-572168023431">1920 - Jack Burchat and Jim MacDougal at Kioshkokwi Lake.</a>
# </h1>
# <h1>
# <a href="/photo/51B95175-3930-478B-A27F-642681554237">Climbing Skymount Tower</a>
# </h1>
# <h1>
# <a href="/photo/70A893A9-5DF3-42A6-BF25-359296275735">ca. 1984 - Crow Tower Cabin</a>
# </h1>
# <h1>
# <a href="/photo/11AABAF5-CCA9-477C-93C4-508066490837">ca. 1957 - Tower cabin</a>
# </h1>
# <h1>
# <a href="/photo/D8A5CAFF-43D3-4B79-BC96-239844795850">Garage, Stonecliffe.</a>
# </h1>
# <h1>
# <a href="/photo/DB3C1053-E0DE-46EB-A304-334919383017">Forest Fire</a>
# </h1>
# <h1>
# <a href="/photo/15AE4EBD-79E2-41DA-B33C-204860349979">In front of old Highland Inn</a>
# </h1>
# <h1>
# <a href="/photo/0B32099D-1534-425A-9355-135232636138">1976 - Outhouse at Preston Lake fire tower cabin</a>
# </h1>
# <h1>
# <a href="/photo/65D33647-0B58-4CF6-9679-447818936270">Picnic in Algonquin Park.</a>
# </h1>
# <h1>
# <a href="/photo/6EFB98ED-BA18-463D-AD7F-541435576003">Jack Burchat and Venus Legree on the Amable du Fond River.</a>
# </h1>
# <h1>
# <a href="/photo/43C0088D-1416-4209-B1CA-811698665925">1962 - Burning ranger cabin at Three Mile Lake</a>
# </h1>
# <h1>
# <a href="/photo/4B5219EC-F8D2-4E12-900F-336242013500">Men posing with cross cut saws in the bush.</a>
# </h1>
# <h1>
# <a href="/photo/5A297BAC-FAE7-4B00-A770-122996321625">Campfire</a>
# </h1>
# <h1>
# <a href="/photo/A76CF13B-AF16-419C-9BD5-082464237950">1977 - Barron Canyon Fire</a>
# </h1>
# <h1>
# <a href="/photo/889588A1-6DD9-4020-954A-700198065756">1922 - Wooden fire tower.</a>
# </h1>
# <h1>
# <a href="/photo/66BDECD5-9F9E-4F42-B62F-626867948480">1974 - Russel Jocko.</a>
# </h1>
# <h1>
# <a href="/photo/518FE138-C11A-48D1-8C76-429030731476">1925 - A. Wilson Dods at Skymount, Cache Lake.</a>
# </h1>
# <h1>
# <a href="/photo/901F5716-428B-4B3B-B9EE-803331212746">ca. 1940 - Loggers taking a lunch break.</a>
# </h1>
# <h1>
# <a href="/photo/BDC1A784-FF96-4F97-B419-171303920540">1897 - Hayes Party</a>
# </h1>
# <h1>
# <a href="/photo/0221C1F1-307D-48F0-8FBD-168725468450">1928 - Fire Rangers James Hyland and Tom O'Shaughnessy</a>
# </h1>
# <h1>
# <a href="/photo/14370802-3ECE-430F-9A7A-278510119724">Fire Creeping 1952</a>
# </h1>
# <h1>
# <a href="/photo/9F1DD187-FACE-40A5-9816-496551134590">1962 - Towerman's cabin</a>
# </h1>
# <h1>
# <a href="/photo/ED616FB5-B984-4D55-B153-851338410780">ca. 1920 - Jack Burchat and team plowing at Kiosk.</a>
# </h1>
# First, we learned some html basics and established contact with the APK Archives server and printed the raw html for the entire page. Then we added in beautiful soup so that we could parse the html for the links and titles that we were looking for. Once we identified that all the links and titles were contained under the pages h1 header sections, we were able to isolate and print all h1 instances, in other words all the things we were looking for. Finally, we used some fancy code that I only sort of understand to make a .csv file, add a header in the .csv, and then print the results of our previous code into the csv. Then voila, we suddenly had a .csv that contained all the links and object titles, with minimal clean up of html neeeded in the csv itself.
#
# For some this notebook may seem dirt simple, but it has been made for an audience of historians or other arts students with literally zero knowledge of coding, just like myself. If you have no idea how to use the command line, or what a string is, if you have never seen html before, don't know where to go to write code, if you don't even know the letters that make up the python language, let alone how the language actually works, then this is the notebook for you. It isn't pretty, nor is it complicated, but it gets the job done, and that's good enough for me.

# %% [markdown]
# ### Further Reading

# %% [markdown]
# Melanie Walsh, "Webscraping Part 1," Introduction to Cultural Analytics and Python, https://melaniewalsh.github.io/Intro-Cultural-Analytics/Data-Collection/Web-Scraping-Part1.html
#
# Melanie Walsh, "Webscraping Part 2," Introduction to Cultural Analytics and Python, https://melaniewalsh.github.io/Intro-Cultural-Analytics/Data-Collection/Web-Scraping-Part2.html
#
# Both these pages form the backbone of my knowledge for the scraper I've put together in this notebook. I did what I was able to do, but these two tutorials go further than I did. In particular, they run through how to use regular expressions to make entire functions that parse the html more quickly and effectively, and they give details as to how to clean up your html data in the notebook before sending your results over to a .csv
#
# Hiren Pattel, "How Webscraping is Transforming the World with its Applications," Towards Data Science, https://towardsdatascience.com/https-medium-com-hiren787-patel-web-scraping-applications-a6f370d316f4
#
# Pattel goes through a vast number of ways that webscrapers are being used more and more in the modern world. In his section on academics, he makes the simple point that academics are all about working with data, and webscraping is all about collecting data, so it naturally follows that scraping could be applied to any kind of work you please. The rest of his article offers many other practical examples of business applications that may inspire new ideas of how to use a scraper.
#
# Martin Breuss, "Beautiful Soup: Build a Webscraper with Python," Real Python, https://realpython.com/beautiful-soup-web-scraper-python/
#
# If you're actually an absolute beginner like me, then you'll need at least three different tutorials to reference in order to make this scraper actually work. Here's one that spends a lot of time explaining the basic theory that underlies these line of codes.Additionally, Breuss explains some of the pitfalls and traps that one can run into when parsing a site which is valuable for when your code inevitably goes wrong and you need to figure out why. A little extra understanding goes a long way towards the trouble shooting process.

# %% [markdown]
# ### References

# %% [markdown]
# Melanie Walsh, "Webscraping Part 1," Introduction to Cultural Analytics and Python, https://melaniewalsh.github.io/Intro-Cultural-Analytics/Data-Collection/Web-Scraping-Part1.html
#
# Melanie Walsh, "Webscraping Part 2," Introduction to Cultural Analytics and Python, https://melaniewalsh.github.io/Intro-Cultural-Analytics/Data-Collection/Web-Scraping-Part2.html
#
# Martin Breuss, "Beautiful Soup: Build a Webscraper with Python," Real Python, https://realpython.com/beautiful-soup-web-scraper-python/
#
# "Writing Scraped Links to a CSV File Using Pyhton 3," StackOverflow, https://stackoverflow.com/questions/47372961/writing-to-scraped-links-to-a-csv-file-using-python3
#
# "What does the Newline='' argument do?", Code Academy Discuss, https://discuss.codecademy.com/t/what-does-the-newline-argument-do/463575
#
# Andrew Schwan, roommate and computer enthusiast
